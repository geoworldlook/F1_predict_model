# %% [markdown]
# <a href="https://colab.research.google.com/github/geoworldlook/F1_predict_model/blob/prediction_2024/Model_F1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras-tuner
# !pip install shap
# Out:
# Requirement already satisfied: keras-tuner in /usr/local/lib/python3.10/dist-packages (1.4.7)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (3.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner) (0.13.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras->keras-tuner) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras-tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras-tuner) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Requirement already satisfied: shap in /usr/local/lib/python3.10/dist-packages (0.46.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.5)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (24.1)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.10/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (3.1.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)

# %% [markdown]
# # Neural Network Model F1
#
# This documentation explains the steps involved in building, training, and evaluating a neural network model for predicting Formula 1 lap times. The model utilizes LSTM layers for time series forecasting based on training and race data for different drivers. The following sections cover the key components, functions, and processes.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
import matplotlib.pyplot as plt
import shap
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
import kerastuner as kt
from keras.metrics import MeanSquaredError, RootMeanSquaredError, MeanAbsolutePercentageError
from tensorflow.keras.losses import Huber

# %% [markdown]
# ## Data Loading
#
# Here, the script loads training and race data for each driver in the `driver_list`. The data files are stored in CSV format and are specific to each driver. The `driver_id` column is removed since it's not necessary for model training.
#
# - `X_train_data`: Features for the training set.
# - `y_train_data`: Target variable (lap time in seconds) for the training set.
# - `X_race_data`: Features for the race set.
# - `y_race_data`: Target variable (lap time in seconds) for the race set.

# %% [markdown]
# ### Explanation of Key Functions
#
# 1. **create_sequences**:
#    - This function converts data into sequential form for LSTM models.
#    - Input: Array of data and sequence length (`seq_length`).
#    - Output: Array of sequences used for training.
#
# 2. **build_model**:
#    - This function builds and compiles an LSTM model.
#    - Input: Hyperparameters (`hp`) such as the number of units and layers.
#    - Output: Compiled Keras model ready for training.
#
# 3. **plot_training_history**:
#    - This function plots the training and validation loss curves over epochs.
#    - Input: Training history object from the model fit.
#    - Output: Visualized training and validation loss over time.
#
# 4. **plot_weight_importance**:
#    - This function visualizes the importance of different features based on the LSTM model's learned weights.
#    - Input: Model weights, feature names, and driver name.
#    - Output: Bar plot of feature importance.

# %% [markdown]
# ## Sequence Creation Function
#
# The `create_sequences` function generates sequences of data for time series forecasting. It slices the dataset into overlapping sequences of length `seq_length`, which is a hyperparameter to be tuned.

# %%
def create_sequences(data, seq_length):
    """
    Converts data into sequences for LSTM models.

    Parameters:
    data (array-like): The input data to be converted into sequences.
    seq_length (int): The length of each sequence.

    Returns:
    np.array: The data converted into sequences.
    """
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequences.append(data[i:i + seq_length])
    return np.array(sequences)

# %% [markdown]
# ## Model Building Function
#
# The `build_model` function defines the architecture of the LSTM neural network model. The function uses `keras-tuner` to optimize hyperparameters, such as:
# - Number of LSTM layers (`num_layers`)
# - Number of units in each LSTM layer (`units`)
# - Activation functions (`activation`, `recurrent_activation`)
# - Optimizer type (`adam`, `rmsprop`, `sgd`)
#
# The model is compiled with the Huber loss function and evaluation metrics like mean absolute error (MAE), mean squared error (MSE), and root mean squared error (RMSE).

# %%
def build_model(hp):
    """
    Build and compile a LSTM model with hyperparameter tuning.

    Args:
        hp (kt.HyperParameters): The hyperparameters to optimize.

    Returns:
        tf.keras.Model: The compiled LSTM model.
    """
    # Define a Sequential model
    model = tf.keras.Sequential()

    # Define the sequence length as a hyperparameter to vary between 2 and 6
    seq_length = hp.Int('seq_length', min_value=2, max_value=6, step=1)

    # Create input sequences from training data based on the chosen sequence length
    X_train_seq = create_sequences(X_train_data, seq_length)
    y_train_seq = create_sequences(y_train_data.values, seq_length)

    # Split the sequences into training and validation sets (80% training, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(X_train_seq, y_train_seq, test_size=0.2, random_state=42)

    # Define the activation function for the LSTM layers as a hyperparameter (can be 'relu', 'tanh', or 'sigmoid')
    activation = hp.Choice('activation', ['relu', 'tanh', 'sigmoid'])

    # Define the recurrent activation function for the LSTM layers as a hyperparameter (either 'sigmoid' or 'tanh')
    recurrent_activation = hp.Choice('recurrent_activation', ['sigmoid', 'tanh'])

    # Loop to add LSTM layers to the model, with a variable number of layers (between 1 and 3)
    for i in range(hp.Int('num_layers', 1, 3)):

        # Add an LSTM layer to the model
        model.add(tf.keras.layers.LSTM(
            # Define the number of units in the LSTM layer as a hyperparameter (between 32 and 256)
            units=hp.Int('units_' + str(i), min_value=32, max_value=256, step=32),

            # Use the chosen activation function
            activation=activation,

            # Use the chosen recurrent activation function
            recurrent_activation=recurrent_activation,

            # Determine if the layer returns sequences (True for all but the last LSTM layer)
            return_sequences=(i < hp.Int('num_layers', 1, 3) - 1),

            # Define the dropout rate for this LSTM layer as a hyperparameter (between 0.0 and 0.5)
            dropout=hp.Float('dropout_' + str(i), min_value=0.0, max_value=0.5, step=0.1),

            # Define the recurrent dropout rate as a hyperparameter (between 0.0 and 0.5)
            recurrent_dropout=hp.Float('recurrent_dropout_' + str(i), min_value=0.0, max_value=0.5, step=0.1),

            # Apply L2 regularization to the kernel weights, with the regularization value as a hyperparameter
            kernel_regularizer=tf.keras.regularizers.l2(hp.Float('kernel_regularizer_' + str(i), min_value=1e-5, max_value=1e-2, sampling='log')),

            # Apply L2 regularization to the bias weights, with the regularization value as a hyperparameter
            bias_regularizer=tf.keras.regularizers.l2(hp.Float('bias_regularizer_' + str(i), min_value=1e-5, max_value=1e-2, sampling='log'))
        ))

    # Add a Dense layer with a variable number of units (between 32 and 256), using 'relu' activation
    model.add(tf.keras.layers.Dense(
        hp.Int('dense_units', min_value=32, max_value=256, step=32),
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(hp.Float('kernel_regularizer_dense', min_value=1e-5, max_value=1e-2, sampling='log')),
        bias_regularizer=tf.keras.regularizers.l2(hp.Float('bias_regularizer_dense', min_value=1e-5, max_value=1e-2, sampling='log'))
    ))

    # Add the final output layer with 1 unit (for regression prediction)
    model.add(tf.keras.layers.Dense(1))

    # Choose the optimizer as a hyperparameter (options: 'adam', 'rmsprop', 'sgd')
    optimizer = hp.Choice('optimizer', ['adam', 'rmsprop', 'sgd'])

    # Configure the optimizer with a learning rate hyperparameter (different options based on optimizer)
    if optimizer == 'adam':
        optimizer = tf.keras.optimizers.Adam(hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log'))
    elif optimizer == 'rmsprop':
        optimizer = tf.keras.optimizers.RMSprop(hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log'))
    else:
        optimizer = tf.keras.optimizers.SGD(hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log'))

    # Compile the model with Huber loss (delta as a hyperparameter) and standard regression metrics
    model.compile(
        optimizer=optimizer,
        loss=Huber(delta=hp.Float('delta', min_value=0.1, max_value=2.0, step=0.1)),
        metrics=['mae', MeanSquaredError(), RootMeanSquaredError(), MeanAbsolutePercentageError()]
    )

    # Return the constructed model
    return model

# %%
def plot_weight_importance(weights, feature_names, driver):
            """
            Function to visualize the importance of features based on the absolute value of the weights.

            Args:
                weights: The weight matrix from the trained model.
                feature_names: Names of the features corresponding to the weight matrix.
                driver: Name of the driver for the title of the plot.
            """
            # Take the absolute value of the weights and average across neurons
            avg_weights = np.mean(np.abs(weights), axis=1)

            # Sort the features based on the average weight
            sorted_idx = np.argsort(avg_weights)[::-1]

            # Create a horizontal bar plot
            plt.figure(figsize=(12, 8))
            plt.barh(range(len(feature_names)), avg_weights[sorted_idx], align='center', color='skyblue')
            plt.yticks(range(len(feature_names)), np.array(feature_names)[sorted_idx])
            plt.xlabel('Average Absolute Weight')
            plt.ylabel('Features')
            plt.title(f'Feature Importance (Weights) for {driver}')

            # Add a threshold for important features (optional)
            threshold = 0.01  # You can adjust this threshold
            plt.axvline(x=threshold, color='r', linestyle='--', label=f'Threshold: {threshold}')
            plt.legend()

            plt.tight_layout()
            plt.show()

# %% [markdown]
# # Initializing Parameters and Driver List
#
# Here, we initialize empty lists to store training and race histories (`all_histories_train`, `all_histories_race`) and the weights of the models (`wage_weights`). The list `driver_list` contains the names of Formula 1 drivers for whom the model will be built.

# %%
all_histories_train = []
all_histories_race = []
wage_weights = []

model_parametr_objective = ['mean_squared_error']
driver_list = ['VER', 'NOR', 'PER', 'LEC', 'PIA', 'RUS', 'HAM','SAI']

# %% [markdown]
# ## Model Training and Evaluation Loop for Multiple Drivers
#
# This section iterates through a list of drivers (`driver_list`). For each driver, the following steps are performed:
#
# 1. **Data Loading**: The training and race data for each driver are loaded from CSV files.
# 2. **Data Preparation**: Sequences for training the model are created.
# 3. **Model Building**: A neural network (LSTM) model is built and trained for each driver.
# 4. **Training the Model**: The model is trained on the training data.
# 5. **Evaluating the Model**: Model performance is evaluated on the race data.
# 6. **Results Visualization**: The training history and feature importance are visualized.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from keras.losses import Huber
from keras.metrics import MeanSquaredError, RootMeanSquaredError, MeanAbsolutePercentageError
import keras_tuner as kt

# Iterate over model objectives and drivers
for type_objective in model_parametr_objective:
    for driver in driver_list:

        # Load the training and race data for each driver
        train_data = pd.read_csv(f"/content/drive/MyDrive/F1_MODEL/with_points/2022_2024/DATA_MEXICO_2024/train_data_scaled_points_{driver}.csv")
        race_data = pd.read_csv(f"/content/drive/MyDrive/F1_MODEL/with_points/2022_2024/DATA_MEXICO_2024/race_data_scaled_points_{driver}.csv")

        # Prepare feature matrices (X) and target vectors (y)
        X_train_data = train_data.drop(['driver_id'], axis=1)
        y_train_data = train_data['LapTime_seconds']
        X_race_data = race_data.drop(['driver_id'], axis=1)
        y_race_data = race_data['LapTime_seconds']

        # Hyperparameter tuning using KerasTuner
        tuner = kt.Hyperband(
            build_model,
            objective=type_objective,
            max_epochs=30,
            factor=3,
            max_consecutive_failed_trials= 5,
            directory=f"/content/drive/MyDrive/F1_MODEL/with_points/models_v3/my_dir_{driver}_{type_objective}_points_huber",
            project_name='f1_lap_time_prediction_points'
        )

        # Set sequence length and create sequences for training
        SEQ_LENGTH = 3
        X_train_seq = create_sequences(X_train_data.values, SEQ_LENGTH)
        y_train_seq = create_sequences(y_train_data.values, SEQ_LENGTH)

        # Create mask to eliminate Nan data
        mask = ~np.isnan(X_train_seq).any(axis=(1, 2))
        X_train_seq = X_train_seq[mask]
        y_train_seq = y_train_seq[mask]

        # Search for the best hyperparameters
        tuner.search(X_train_seq, y_train_seq, epochs=30, validation_split=0.2)

        # Retrieve the best hyperparameters
        best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

        # Build the model using the best hyperparameters
        model = tuner.hypermodel.build(best_hps)

        # Train the model on training data
        history_train = model.fit(X_train_seq, y_train_seq, epochs=35, validation_split=0.2, batch_size=32)

        # Create sequences from race data using the best sequence length
        X_race_seq = create_sequences(X_race_data.values, best_hps.get('seq_length'))
        y_race_seq = create_sequences(y_race_data.values, best_hps.get('seq_length'))

        # Fine-tune the model on race data
        history_race = model.fit(X_race_seq, y_race_seq, validation_split=0.2, epochs=20, batch_size=32)

        # Append the training and race histories for analysis
        all_histories_train.append(history_train)
        all_histories_race.append(history_race)

        # Save model weights for future use
        weights = model.get_weights()[0]
        wage_weights.append(weights)

        # Base stats about model
        print(driver)
        print(f"Best seq: {best_hps.get('seq_length')}")
        print(f"Best number of layer LSTM: {best_hps.get('num_layers')}")
        for i in range(best_hps.get('num_layers')):
          print(f"Number of units in Dense {i+1}: {best_hps.get('units_' + str(i))}")
        print(f"Number of units in Dense: {best_hps.get('dense_units')}")
        print(f"Best optimizer: {best_hps.get('optimizer')}")

        model.save(f"/content/drive/MyDrive/F1_MODEL/with_points/2022_2024/model_v3/model_trained_with_best_hyperparams_and_race_data_{driver}_{type_objective}_points_huber.h5")
# Out:
# Trial 82 Complete [00h 01m 22s]
# mean_squared_error: 0.5214254260063171
#
# Best mean_squared_error So Far: 0.4120148718357086
# Total elapsed time: 41d 20h 00m 59s
# Epoch 1/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 1.0159 - mae: 0.8237 - mean_absolute_percentage_error: 198.5906 - mean_squared_error: 1.1233 - root_mean_squared_error: 1.0572 - val_loss: 0.6777 - val_mae: 0.5735 - val_mean_absolute_percentage_error: 217.4494 - val_mean_squared_error: 0.5997 - val_root_mean_squared_error: 0.7744
# Epoch 2/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.6003 - mae: 0.5183 - mean_absolute_percentage_error: 443.8970 - mean_squared_error: 0.4997 - root_mean_squared_error: 0.7068 - val_loss: 0.5486 - val_mae: 0.5408 - val_mean_absolute_percentage_error: 209.0532 - val_mean_squared_error: 0.5488 - val_root_mean_squared_error: 0.7408
# Epoch 3/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4942 - mae: 0.5049 - mean_absolute_percentage_error: 480.9415 - mean_squared_error: 0.4792 - root_mean_squared_error: 0.6921 - val_loss: 0.4828 - val_mae: 0.5514 - val_mean_absolute_percentage_error: 194.0214 - val_mean_squared_error: 0.5611 - val_root_mean_squared_error: 0.7490
# Epoch 4/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4173 - mae: 0.4854 - mean_absolute_percentage_error: 554.9219 - mean_squared_error: 0.4519 - root_mean_squared_error: 0.6720 - val_loss: 0.4101 - val_mae: 0.5184 - val_mean_absolute_percentage_error: 221.9666 - val_mean_squared_error: 0.5028 - val_root_mean_squared_error: 0.7091
# Epoch 5/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.3658 - mae: 0.4762 - mean_absolute_percentage_error: 320.4655 - mean_squared_error: 0.4302 - root_mean_squared_error: 0.6558 - val_loss: 0.3780 - val_mae: 0.5157 - val_mean_absolute_percentage_error: 206.1761 - val_mean_squared_error: 0.4996 - val_root_mean_squared_error: 0.7068
# Epoch 6/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.3314 - mae: 0.4652 - mean_absolute_percentage_error: 506.6440 - mean_squared_error: 0.4165 - root_mean_squared_error: 0.6451 - val_loss: 0.3554 - val_mae: 0.5077 - val_mean_absolute_percentage_error: 204.5546 - val_mean_squared_error: 0.4968 - val_root_mean_squared_error: 0.7048
# Epoch 7/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3106 - mae: 0.4589 - mean_absolute_percentage_error: 342.3755 - mean_squared_error: 0.4140 - root_mean_squared_error: 0.6431 - val_loss: 0.3416 - val_mae: 0.5157 - val_mean_absolute_percentage_error: 190.6605 - val_mean_squared_error: 0.5011 - val_root_mean_squared_error: 0.7079
# Epoch 8/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2980 - mae: 0.4644 - mean_absolute_percentage_error: 364.6291 - mean_squared_error: 0.4175 - root_mean_squared_error: 0.6458 - val_loss: 0.3197 - val_mae: 0.4955 - val_mean_absolute_percentage_error: 216.8395 - val_mean_squared_error: 0.4785 - val_root_mean_squared_error: 0.6918
# Epoch 9/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2886 - mae: 0.4668 - mean_absolute_percentage_error: 316.9969 - mean_squared_error: 0.4211 - root_mean_squared_error: 0.6488 - val_loss: 0.3091 - val_mae: 0.4946 - val_mean_absolute_percentage_error: 203.8727 - val_mean_squared_error: 0.4766 - val_root_mean_squared_error: 0.6904
# Epoch 10/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2763 - mae: 0.4581 - mean_absolute_percentage_error: 278.3857 - mean_squared_error: 0.4142 - root_mean_squared_error: 0.6434 - val_loss: 0.3011 - val_mae: 0.4972 - val_mean_absolute_percentage_error: 200.6261 - val_mean_squared_error: 0.4770 - val_root_mean_squared_error: 0.6906
# Epoch 11/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2700 - mae: 0.4661 - mean_absolute_percentage_error: 401.5764 - mean_squared_error: 0.4166 - root_mean_squared_error: 0.6454 - val_loss: 0.2950 - val_mae: 0.4970 - val_mean_absolute_percentage_error: 199.8458 - val_mean_squared_error: 0.4787 - val_root_mean_squared_error: 0.6919
# Epoch 12/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2542 - mae: 0.4523 - mean_absolute_percentage_error: 486.4587 - mean_squared_error: 0.3980 - root_mean_squared_error: 0.6304 - val_loss: 0.2875 - val_mae: 0.4939 - val_mean_absolute_percentage_error: 201.0103 - val_mean_squared_error: 0.4748 - val_root_mean_squared_error: 0.6890
# Epoch 13/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2587 - mae: 0.4625 - mean_absolute_percentage_error: 391.2461 - mean_squared_error: 0.4184 - root_mean_squared_error: 0.6464 - val_loss: 0.2818 - val_mae: 0.5019 - val_mean_absolute_percentage_error: 217.7585 - val_mean_squared_error: 0.4725 - val_root_mean_squared_error: 0.6874
# Epoch 14/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2436 - mae: 0.4514 - mean_absolute_percentage_error: 611.5311 - mean_squared_error: 0.3978 - root_mean_squared_error: 0.6306 - val_loss: 0.2772 - val_mae: 0.4962 - val_mean_absolute_percentage_error: 220.7859 - val_mean_squared_error: 0.4718 - val_root_mean_squared_error: 0.6869
# Epoch 15/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2450 - mae: 0.4580 - mean_absolute_percentage_error: 361.9227 - mean_squared_error: 0.4097 - root_mean_squared_error: 0.6401 - val_loss: 0.2729 - val_mae: 0.4955 - val_mean_absolute_percentage_error: 203.4728 - val_mean_squared_error: 0.4723 - val_root_mean_squared_error: 0.6872
# Epoch 16/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2400 - mae: 0.4574 - mean_absolute_percentage_error: 393.6508 - mean_squared_error: 0.4071 - root_mean_squared_error: 0.6379 - val_loss: 0.2706 - val_mae: 0.4999 - val_mean_absolute_percentage_error: 202.3360 - val_mean_squared_error: 0.4751 - val_root_mean_squared_error: 0.6892
# Epoch 17/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.2480 - mae: 0.4722 - mean_absolute_percentage_error: 367.3057 - mean_squared_error: 0.4295 - root_mean_squared_error: 0.6552 - val_loss: 0.2658 - val_mae: 0.4876 - val_mean_absolute_percentage_error: 199.0492 - val_mean_squared_error: 0.4715 - val_root_mean_squared_error: 0.6867
# Epoch 18/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.2357 - mae: 0.4571 - mean_absolute_percentage_error: 392.5844 - mean_squared_error: 0.4114 - root_mean_squared_error: 0.6413 - val_loss: 0.2626 - val_mae: 0.4940 - val_mean_absolute_percentage_error: 205.6448 - val_mean_squared_error: 0.4706 - val_root_mean_squared_error: 0.6860
# Epoch 19/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.2377 - mae: 0.4661 - mean_absolute_percentage_error: 358.2750 - mean_squared_error: 0.4209 - root_mean_squared_error: 0.6487 - val_loss: 0.2589 - val_mae: 0.4890 - val_mean_absolute_percentage_error: 204.8020 - val_mean_squared_error: 0.4677 - val_root_mean_squared_error: 0.6839
# Epoch 20/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2333 - mae: 0.4631 - mean_absolute_percentage_error: 396.0685 - mean_squared_error: 0.4165 - root_mean_squared_error: 0.6452 - val_loss: 0.2577 - val_mae: 0.4975 - val_mean_absolute_percentage_error: 209.7732 - val_mean_squared_error: 0.4694 - val_root_mean_squared_error: 0.6851
# Epoch 21/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2411 - mae: 0.4743 - mean_absolute_percentage_error: 503.1464 - mean_squared_error: 0.4365 - root_mean_squared_error: 0.6606 - val_loss: 0.2549 - val_mae: 0.4868 - val_mean_absolute_percentage_error: 203.9700 - val_mean_squared_error: 0.4678 - val_root_mean_squared_error: 0.6840
# Epoch 22/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2336 - mae: 0.4660 - mean_absolute_percentage_error: 423.4368 - mean_squared_error: 0.4253 - root_mean_squared_error: 0.6515 - val_loss: 0.2541 - val_mae: 0.4895 - val_mean_absolute_percentage_error: 200.1135 - val_mean_squared_error: 0.4696 - val_root_mean_squared_error: 0.6852
# Epoch 23/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2192 - mae: 0.4493 - mean_absolute_percentage_error: 423.8859 - mean_squared_error: 0.3990 - root_mean_squared_error: 0.6311 - val_loss: 0.2554 - val_mae: 0.5083 - val_mean_absolute_percentage_error: 212.4808 - val_mean_squared_error: 0.4745 - val_root_mean_squared_error: 0.6889
# Epoch 24/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2210 - mae: 0.4602 - mean_absolute_percentage_error: 422.2553 - mean_squared_error: 0.4048 - root_mean_squared_error: 0.6362 - val_loss: 0.2514 - val_mae: 0.4948 - val_mean_absolute_percentage_error: 215.0328 - val_mean_squared_error: 0.4681 - val_root_mean_squared_error: 0.6842
# Epoch 25/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2175 - mae: 0.4537 - mean_absolute_percentage_error: 440.4679 - mean_squared_error: 0.3998 - root_mean_squared_error: 0.6321 - val_loss: 0.2539 - val_mae: 0.5027 - val_mean_absolute_percentage_error: 225.7968 - val_mean_squared_error: 0.4743 - val_root_mean_squared_error: 0.6887
# Epoch 26/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2185 - mae: 0.4504 - mean_absolute_percentage_error: 380.4123 - mean_squared_error: 0.4036 - root_mean_squared_error: 0.6351 - val_loss: 0.2496 - val_mae: 0.4931 - val_mean_absolute_percentage_error: 206.1302 - val_mean_squared_error: 0.4680 - val_root_mean_squared_error: 0.6841
# Epoch 27/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2228 - mae: 0.4592 - mean_absolute_percentage_error: 480.4911 - mean_squared_error: 0.4132 - root_mean_squared_error: 0.6427 - val_loss: 0.2594 - val_mae: 0.5206 - val_mean_absolute_percentage_error: 235.4562 - val_mean_squared_error: 0.4874 - val_root_mean_squared_error: 0.6982
# Epoch 28/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2227 - mae: 0.4627 - mean_absolute_percentage_error: 286.6095 - mean_squared_error: 0.4145 - root_mean_squared_error: 0.6437 - val_loss: 0.2500 - val_mae: 0.4981 - val_mean_absolute_percentage_error: 201.6794 - val_mean_squared_error: 0.4707 - val_root_mean_squared_error: 0.6861
# Epoch 29/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2177 - mae: 0.4542 - mean_absolute_percentage_error: 328.8844 - mean_squared_error: 0.4054 - root_mean_squared_error: 0.6366 - val_loss: 0.2533 - val_mae: 0.4983 - val_mean_absolute_percentage_error: 189.8552 - val_mean_squared_error: 0.4786 - val_root_mean_squared_error: 0.6918
# Epoch 30/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2236 - mae: 0.4603 - mean_absolute_percentage_error: 464.1188 - mean_squared_error: 0.4175 - root_mean_squared_error: 0.6461 - val_loss: 0.2478 - val_mae: 0.4916 - val_mean_absolute_percentage_error: 205.8006 - val_mean_squared_error: 0.4672 - val_root_mean_squared_error: 0.6835
# Epoch 31/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2158 - mae: 0.4514 - mean_absolute_percentage_error: 360.1761 - mean_squared_error: 0.4019 - root_mean_squared_error: 0.6339 - val_loss: 0.2473 - val_mae: 0.4879 - val_mean_absolute_percentage_error: 204.4309 - val_mean_squared_error: 0.4668 - val_root_mean_squared_error: 0.6832
# Epoch 32/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2208 - mae: 0.4604 - mean_absolute_percentage_error: 509.5478 - mean_squared_error: 0.4127 - root_mean_squared_error: 0.6424 - val_loss: 0.2481 - val_mae: 0.4947 - val_mean_absolute_percentage_error: 204.3099 - val_mean_squared_error: 0.4689 - val_root_mean_squared_error: 0.6848
# Epoch 33/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2259 - mae: 0.4664 - mean_absolute_percentage_error: 340.1061 - mean_squared_error: 0.4234 - root_mean_squared_error: 0.6504 - val_loss: 0.2485 - val_mae: 0.4832 - val_mean_absolute_percentage_error: 211.6716 - val_mean_squared_error: 0.4695 - val_root_mean_squared_error: 0.6852
# Epoch 34/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2173 - mae: 0.4507 - mean_absolute_percentage_error: 428.7049 - mean_squared_error: 0.4063 - root_mean_squared_error: 0.6373 - val_loss: 0.2462 - val_mae: 0.4842 - val_mean_absolute_percentage_error: 205.8872 - val_mean_squared_error: 0.4654 - val_root_mean_squared_error: 0.6822
# Epoch 35/35
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2225 - mae: 0.4605 - mean_absolute_percentage_error: 440.2571 - mean_squared_error: 0.4183 - root_mean_squared_error: 0.6467 - val_loss: 0.2481 - val_mae: 0.4825 - val_mean_absolute_percentage_error: 204.8025 - val_mean_squared_error: 0.4696 - val_root_mean_squared_error: 0.6853
# Epoch 1/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.0450 - mae: 0.1471 - mean_absolute_percentage_error: 63.8014 - mean_squared_error: 0.0648 - root_mean_squared_error: 0.2528 - val_loss: 0.0355 - val_mae: 0.1264 - val_mean_absolute_percentage_error: 28.4475 - val_mean_squared_error: 0.0470 - val_root_mean_squared_error: 0.2168
# Epoch 2/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0389 - mae: 0.1274 - mean_absolute_percentage_error: 61.2445 - mean_squared_error: 0.0549 - root_mean_squared_error: 0.2338 - val_loss: 0.0297 - val_mae: 0.0984 - val_mean_absolute_percentage_error: 25.4154 - val_mean_squared_error: 0.0373 - val_root_mean_squared_error: 0.1932
# Epoch 3/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0329 - mae: 0.1194 - mean_absolute_percentage_error: 55.2948 - mean_squared_error: 0.0445 - root_mean_squared_error: 0.2105 - val_loss: 0.0275 - val_mae: 0.0800 - val_mean_absolute_percentage_error: 20.5138 - val_mean_squared_error: 0.0340 - val_root_mean_squared_error: 0.1844
# Epoch 4/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0380 - mae: 0.1291 - mean_absolute_percentage_error: 65.1506 - mean_squared_error: 0.0554 - root_mean_squared_error: 0.2351 - val_loss: 0.0316 - val_mae: 0.1273 - val_mean_absolute_percentage_error: 25.4001 - val_mean_squared_error: 0.0437 - val_root_mean_squared_error: 0.2089
# Epoch 5/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0346 - mae: 0.1223 - mean_absolute_percentage_error: 64.3211 - mean_squared_error: 0.0494 - root_mean_squared_error: 0.2220 - val_loss: 0.0307 - val_mae: 0.1188 - val_mean_absolute_percentage_error: 22.1496 - val_mean_squared_error: 0.0426 - val_root_mean_squared_error: 0.2064
# Epoch 6/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0354 - mae: 0.1234 - mean_absolute_percentage_error: 57.4847 - mean_squared_error: 0.0516 - root_mean_squared_error: 0.2270 - val_loss: 0.0287 - val_mae: 0.1035 - val_mean_absolute_percentage_error: 25.0132 - val_mean_squared_error: 0.0379 - val_root_mean_squared_error: 0.1947
# Epoch 7/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0312 - mae: 0.1150 - mean_absolute_percentage_error: 54.5759 - mean_squared_error: 0.0435 - root_mean_squared_error: 0.2083 - val_loss: 0.0301 - val_mae: 0.1172 - val_mean_absolute_percentage_error: 27.2384 - val_mean_squared_error: 0.0411 - val_root_mean_squared_error: 0.2028
# Epoch 8/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0354 - mae: 0.1220 - mean_absolute_percentage_error: 53.4651 - mean_squared_error: 0.0523 - root_mean_squared_error: 0.2286 - val_loss: 0.0270 - val_mae: 0.0904 - val_mean_absolute_percentage_error: 19.8279 - val_mean_squared_error: 0.0361 - val_root_mean_squared_error: 0.1900
# Epoch 9/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0341 - mae: 0.1187 - mean_absolute_percentage_error: 59.6581 - mean_squared_error: 0.0502 - root_mean_squared_error: 0.2239 - val_loss: 0.0338 - val_mae: 0.1468 - val_mean_absolute_percentage_error: 26.2947 - val_mean_squared_error: 0.0504 - val_root_mean_squared_error: 0.2244
# Epoch 10/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0321 - mae: 0.1197 - mean_absolute_percentage_error: 60.3006 - mean_squared_error: 0.0465 - root_mean_squared_error: 0.2154 - val_loss: 0.0282 - val_mae: 0.1062 - val_mean_absolute_percentage_error: 21.8762 - val_mean_squared_error: 0.0392 - val_root_mean_squared_error: 0.1980
# Epoch 11/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0335 - mae: 0.1205 - mean_absolute_percentage_error: 59.2109 - mean_squared_error: 0.0495 - root_mean_squared_error: 0.2223 - val_loss: 0.0280 - val_mae: 0.1008 - val_mean_absolute_percentage_error: 25.3652 - val_mean_squared_error: 0.0383 - val_root_mean_squared_error: 0.1958
# Epoch 12/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0338 - mae: 0.1195 - mean_absolute_percentage_error: 70.1959 - mean_squared_error: 0.0504 - root_mean_squared_error: 0.2239 - val_loss: 0.0297 - val_mae: 0.1191 - val_mean_absolute_percentage_error: 28.3840 - val_mean_squared_error: 0.0416 - val_root_mean_squared_error: 0.2040
# Epoch 13/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0327 - mae: 0.1234 - mean_absolute_percentage_error: 64.4979 - mean_squared_error: 0.0484 - root_mean_squared_error: 0.2196 - val_loss: 0.0381 - val_mae: 0.1740 - val_mean_absolute_percentage_error: 35.1324 - val_mean_squared_error: 0.0583 - val_root_mean_squared_error: 0.2414
# Epoch 14/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.0321 - mae: 0.1208 - mean_absolute_percentage_error: 53.3716 - mean_squared_error: 0.0471 - root_mean_squared_error: 0.2163 - val_loss: 0.0334 - val_mae: 0.1303 - val_mean_absolute_percentage_error: 29.9114 - val_mean_squared_error: 0.0493 - val_root_mean_squared_error: 0.2221
# Epoch 15/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0300 - mae: 0.1155 - mean_absolute_percentage_error: 50.8991 - mean_squared_error: 0.0433 - root_mean_squared_error: 0.2074 - val_loss: 0.0360 - val_mae: 0.1641 - val_mean_absolute_percentage_error: 27.5165 - val_mean_squared_error: 0.0560 - val_root_mean_squared_error: 0.2366
# Epoch 16/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0339 - mae: 0.1214 - mean_absolute_percentage_error: 67.1730 - mean_squared_error: 0.0513 - root_mean_squared_error: 0.2263 - val_loss: 0.0291 - val_mae: 0.1191 - val_mean_absolute_percentage_error: 23.6975 - val_mean_squared_error: 0.0420 - val_root_mean_squared_error: 0.2050
# Epoch 17/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0320 - mae: 0.1202 - mean_absolute_percentage_error: 62.7611 - mean_squared_error: 0.0474 - root_mean_squared_error: 0.2174 - val_loss: 0.0314 - val_mae: 0.1348 - val_mean_absolute_percentage_error: 30.9897 - val_mean_squared_error: 0.0460 - val_root_mean_squared_error: 0.2146
# Epoch 18/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0343 - mae: 0.1235 - mean_absolute_percentage_error: 61.7939 - mean_squared_error: 0.0522 - root_mean_squared_error: 0.2283 - val_loss: 0.0296 - val_mae: 0.1298 - val_mean_absolute_percentage_error: 28.8523 - val_mean_squared_error: 0.0428 - val_root_mean_squared_error: 0.2069
# Epoch 19/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0346 - mae: 0.1247 - mean_absolute_percentage_error: 56.2920 - mean_squared_error: 0.0530 - root_mean_squared_error: 0.2299 - val_loss: 0.0266 - val_mae: 0.0919 - val_mean_absolute_percentage_error: 24.4502 - val_mean_squared_error: 0.0371 - val_root_mean_squared_error: 0.1925
# Epoch 20/20
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0320 - mae: 0.1197 - mean_absolute_percentage_error: 53.3018 - mean_squared_error: 0.0480 - root_mean_squared_error: 0.2183 - val_loss: 0.0257 - val_mae: 0.0846 - val_mean_absolute_percentage_error: 20.1541 - val_mean_squared_error: 0.0355 - val_root_mean_squared_error: 0.1885
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# SAI
# Best seq: 5
# Best number of layer LSTM: 3
# Number of units in Dense 1: 32
# Number of units in Dense 2: 32
# Number of units in Dense 3: 64
# Number of units in Dense: 160
# Best optimizer: rmsprop

# %% [markdown]
# ### Explanation of Variables:
#
# - `type_objective`: The objective to be optimized during tuning (e.g., 'mean_squared_error', 'mae').
# - `driver`: The driver identifier, used to load specific training and race data for each driver.
# - `train_data`: Pandas DataFrame containing the scaled training data for the driver.
# - `race_data`: Pandas DataFrame containing the scaled race data for the driver.
# - `X_train_data`, `y_train_data`: The training input features and target variable (lap times) for the model.
# - `X_race_data`, `y_race_data`: The race input features and target variable (lap times).
# - `tuner`: Keras Tuner object, used to search for optimal hyperparameters using Hyperband.
# - `SEQ_LENGTH`: The number of time steps used to create sequences for the LSTM input.
# - `X_train_seq`, `y_train_seq`: Sequences of input features and target values, generated from the training data.
# - `X_race_seq`, `y_race_seq`: Sequences of input features and target values, generated from the race data.
# - `best_hps`: The optimal hyperparameters found during the tuning process.
# - `history_train`: The training history of the model, used for analysis of training performance.
# - `history_race`: The race data history, used for analysis of how the model performs on race data.
# - `all_histories_train`, `all_histories_race`: Lists storing training and race histories for each driver.

# %%
# Importing the necessary library for plotting
import matplotlib.pyplot as plt

# Function to plot the training and validation loss for each driver
def plot_training_history(history_train, history_race, driver):
    """
    Plots the training and validation loss for both the training and race datasets for a given driver.

    Parameters:
    - history_train (keras.callbacks.History): The training history object, which contains the loss values
      and validation loss values for the training data over the epochs.
    - history_race (keras.callbacks.History): The training history object for race data, which stores the
      loss and validation loss values over the epochs.
    - driver (str): The driver's identifier (e.g., 'VER', 'HAM') used to label the plot.

    This function creates two subplots:
    1. The first subplot shows the training and validation loss for the training data.
    2. The second subplot shows the training and validation loss for the race data.
    """

    # Create a new figure for the plots with a specified size
    plt.figure(figsize=(14, 6))

    # First subplot: Training Loss and Validation Loss for the training data
    plt.subplot(1, 2, 1)
    plt.plot(history_train.history['loss'], label='Training Loss')  # Plot training loss over epochs
    plt.plot(history_train.history['val_loss'], label='Validation Loss')  # Plot validation loss over epochs
    plt.title(f'Training Loss for {driver}')  # Set the title for the training plot
    plt.xlabel('Epochs')  # X-axis label
    plt.ylabel('Loss')  # Y-axis label (loss values)
    plt.legend()  # Add a legend to distinguish between training and validation loss

    # Second subplot: Training Loss and Validation Loss for the race data
    plt.subplot(1, 2, 2)
    plt.plot(history_race.history['loss'], label='Race Training Loss')  # Plot race training loss over epochs
    plt.plot(history_race.history['val_loss'], label='Race Validation Loss')  # Plot race validation loss over epochs
    plt.title(f'Race Loss for {driver}')  # Set the title for the race plot
    plt.xlabel('Epochs')  # X-axis label
    plt.ylabel('Loss')  # Y-axis label (loss values)
    plt.legend()  # Add a legend to distinguish between race training and validation loss

    # Adjust the layout of the plots to avoid overlap
    plt.tight_layout()

    # Display the plots
    plt.show()

# Plot training and validation performance for each driver
for i, driver in enumerate(driver_list):
    """
    Looping through each driver in the driver_list and plotting the training history and race history
    using the plot_training_history function.

    Parameters:
    - i (int): The index of the current driver in the driver_list.
    - driver (str): The driver's identifier (e.g., 'VER', 'HAM').
    - all_histories_train (list): A list of training history objects for each driver.
    - all_histories_race (list): A list of race history objects for each driver.

    For each driver, the function retrieves the corresponding training and race history,
    then calls the plot_training_history function to create the plots.
    """
    plot_training_history(all_histories_train[i], all_histories_race[i], driver)
