# %% [markdown]
# <a href="https://colab.research.google.com/github/geoworldlook/F1_predict_model/blob/prediction_2024/Model_F1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras-tuner
# !pip install shap
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (3.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.32.3)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner) (0.13.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras->keras-tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras->keras-tuner) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras-tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras->keras-tuner) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.9 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5
# Requirement already satisfied: shap in /usr/local/lib/python3.10/dist-packages (0.46.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.6)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (24.1)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.10/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (3.1.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)

# %% [markdown]
# # Neural Network Model F1
#
# This documentation explains the steps involved in building, training, and evaluating a neural network model for predicting Formula 1 lap times. The model utilizes LSTM layers for time series forecasting based on training and race data for different drivers. The following sections cover the key components, functions, and processes.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
import matplotlib.pyplot as plt
import shap
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
import kerastuner as kt
from keras.metrics import MeanSquaredError, RootMeanSquaredError, MeanAbsolutePercentageError
from tensorflow.keras.losses import Huber
# Out:
# <ipython-input-2-93ba6c01e819>:9: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   import kerastuner as kt

# %% [markdown]
# ## Data Loading
#
# Here, the script loads training and race data for each driver in the `driver_list`. The data files are stored in CSV format and are specific to each driver. The `driver_id` column is removed since it's not necessary for model training.
#
# - `X_train_data`: Features for the training set.
# - `y_train_data`: Target variable (lap time in seconds) for the training set.
# - `X_race_data`: Features for the race set.
# - `y_race_data`: Target variable (lap time in seconds) for the race set.

# %% [markdown]
# ### Explanation of Key Functions
#
# 1. **create_sequences**:
#    - This function converts data into sequential form for LSTM models.
#    - Input: Array of data and sequence length (`seq_length`).
#    - Output: Array of sequences used for training.
#
# 2. **build_model**:
#    - This function builds and compiles an LSTM model.
#    - Input: Hyperparameters (`hp`) such as the number of units and layers.
#    - Output: Compiled Keras model ready for training.
#
# 3. **plot_training_history**:
#    - This function plots the training and validation loss curves over epochs.
#    - Input: Training history object from the model fit.
#    - Output: Visualized training and validation loss over time.
#
# 4. **plot_weight_importance**:
#    - This function visualizes the importance of different features based on the LSTM model's learned weights.
#    - Input: Model weights, feature names, and driver name.
#    - Output: Bar plot of feature importance.

# %% [markdown]
# ## Sequence Creation Function
#
# The `create_sequences` function generates sequences of data for time series forecasting. It slices the dataset into overlapping sequences of length `seq_length`, which is a hyperparameter to be tuned.

# %%
def create_sequences(data, seq_length):
    """
    Converts data into sequences for LSTM models.

    Parameters:
    data (array-like): The input data to be converted into sequences.
    seq_length (int): The length of each sequence.

    Returns:
    np.array: The data converted into sequences.
    """
    sequences = []
    for i in range(len(data) - seq_length + 1):
        sequences.append(data[i:i + seq_length])
    return np.array(sequences)

# %% [markdown]
# ## Model Building Function
#
# The `build_model` function defines the architecture of the LSTM neural network model. The function uses `keras-tuner` to optimize hyperparameters, such as:
# - Number of LSTM layers (`num_layers`)
# - Number of units in each LSTM layer (`units`)
# - Activation functions (`activation`, `recurrent_activation`)
# - Optimizer type (`adam`, `rmsprop`, `sgd`)
#
# The model is compiled with the Huber loss function and evaluation metrics like mean absolute error (MAE), mean squared error (MSE), and root mean squared error (RMSE).

# %%
def build_model(hp):
    """
    Build and compile a LSTM model with hyperparameter tuning.

    Args:
        hp (kt.HyperParameters): The hyperparameters to optimize.

    Returns:
        tf.keras.Model: The compiled LSTM model.
    """
    # Define a Sequential model
    model = tf.keras.Sequential()

    # Define the sequence length as a hyperparameter to vary between 2 and 6
    seq_length = hp.Int('seq_length', min_value=2, max_value=6, step=1)

    # Create input sequences from training data based on the chosen sequence length
    X_train_seq = create_sequences(X_train_data, seq_length)
    y_train_seq = create_sequences(y_train_data.values, seq_length)

    # Split the sequences into training and validation sets (80% training, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(X_train_seq, y_train_seq, test_size=0.2, random_state=42)

    # Define the activation function for the LSTM layers as a hyperparameter (can be 'relu', 'tanh', or 'sigmoid')
    activation = hp.Choice('activation', ['relu', 'tanh', 'sigmoid'])

    # Define the recurrent activation function for the LSTM layers as a hyperparameter (either 'sigmoid' or 'tanh')
    recurrent_activation = hp.Choice('recurrent_activation', ['sigmoid', 'tanh'])

    # Loop to add LSTM layers to the model, with a variable number of layers (between 1 and 3)
    for i in range(hp.Int('num_layers', 1, 3)):

        # Add an LSTM layer to the model
        model.add(tf.keras.layers.LSTM(
            # Define the number of units in the LSTM layer as a hyperparameter (between 32 and 256)
            units=hp.Int('units_' + str(i), min_value=32, max_value=256, step=32),

            # Use the chosen activation function
            activation=activation,

            # Use the chosen recurrent activation function
            recurrent_activation=recurrent_activation,

            # Determine if the layer returns sequences (True for all but the last LSTM layer)
            return_sequences=(i < hp.Int('num_layers', 1, 3) - 1),

            # Define the dropout rate for this LSTM layer as a hyperparameter (between 0.0 and 0.5)
            dropout=hp.Float('dropout_' + str(i), min_value=0.0, max_value=0.5, step=0.1),

            # Define the recurrent dropout rate as a hyperparameter (between 0.0 and 0.5)
            recurrent_dropout=hp.Float('recurrent_dropout_' + str(i), min_value=0.0, max_value=0.5, step=0.1),

            # Apply L2 regularization to the kernel weights, with the regularization value as a hyperparameter
            kernel_regularizer=tf.keras.regularizers.l2(hp.Float('kernel_regularizer_' + str(i), min_value=1e-5, max_value=1e-2, sampling='log')),

            # Apply L2 regularization to the bias weights, with the regularization value as a hyperparameter
            bias_regularizer=tf.keras.regularizers.l2(hp.Float('bias_regularizer_' + str(i), min_value=1e-5, max_value=1e-2, sampling='log'))
        ))

    # Add a Dense layer with a variable number of units (between 32 and 256), using 'relu' activation
    model.add(tf.keras.layers.Dense(
        hp.Int('dense_units', min_value=32, max_value=256, step=32),
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.l2(hp.Float('kernel_regularizer_dense', min_value=1e-5, max_value=1e-2, sampling='log')),
        bias_regularizer=tf.keras.regularizers.l2(hp.Float('bias_regularizer_dense', min_value=1e-5, max_value=1e-2, sampling='log'))
    ))

    # Add the final output layer with 1 unit (for regression prediction)
    model.add(tf.keras.layers.Dense(1))

    # Choose the optimizer as a hyperparameter (options: 'adam', 'rmsprop', 'sgd')
    optimizer = hp.Choice('optimizer', ['adam', 'rmsprop', 'sgd'])

    # Configure the optimizer with a learning rate hyperparameter (different options based on optimizer)
    if optimizer == 'adam':
        optimizer = tf.keras.optimizers.Adam(hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log'))
    elif optimizer == 'rmsprop':
        optimizer = tf.keras.optimizers.RMSprop(hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log'))
    else:
        optimizer = tf.keras.optimizers.SGD(hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log'))

    # Compile the model with Huber loss (delta as a hyperparameter) and standard regression metrics
    model.compile(
        optimizer=optimizer,
        loss=Huber(delta=hp.Float('delta', min_value=0.1, max_value=2.0, step=0.1)),
        metrics=['mae', MeanSquaredError(), RootMeanSquaredError(), MeanAbsolutePercentageError()]
    )

    # Return the constructed model
    return model

# %%
def plot_weight_importance(weights, feature_names, driver):
            """
            Function to visualize the importance of features based on the absolute value of the weights.

            Args:
                weights: The weight matrix from the trained model.
                feature_names: Names of the features corresponding to the weight matrix.
                driver: Name of the driver for the title of the plot.
            """
            # Take the absolute value of the weights and average across neurons
            avg_weights = np.mean(np.abs(weights), axis=1)

            # Sort the features based on the average weight
            sorted_idx = np.argsort(avg_weights)[::-1]

            # Create a horizontal bar plot
            plt.figure(figsize=(12, 8))
            plt.barh(range(len(feature_names)), avg_weights[sorted_idx], align='center', color='skyblue')
            plt.yticks(range(len(feature_names)), np.array(feature_names)[sorted_idx])
            plt.xlabel('Average Absolute Weight')
            plt.ylabel('Features')
            plt.title(f'Feature Importance (Weights) for {driver}')

            # Add a threshold for important features (optional)
            threshold = 0.01  # You can adjust this threshold
            plt.axvline(x=threshold, color='r', linestyle='--', label=f'Threshold: {threshold}')
            plt.legend()

            plt.tight_layout()
            plt.show()

# %% [markdown]
# # Initializing Parameters and Driver List
#
# Here, we initialize empty lists to store training and race histories (`all_histories_train`, `all_histories_race`) and the weights of the models (`wage_weights`). The list `driver_list` contains the names of Formula 1 drivers for whom the model will be built.

# %%
all_histories_train = []
all_histories_race = []
wage_weights = []

model_parametr_objective = ['mean_squared_error']
driver_list = ['VER', 'NOR', 'PER', 'LEC', 'PIA', 'RUS', 'HAM','SAI']

# %% [markdown]
# ## Model Training and Evaluation Loop for Multiple Drivers
#
# This section iterates through a list of drivers (`driver_list`). For each driver, the following steps are performed:
#
# 1. **Data Loading**: The training and race data for each driver are loaded from CSV files.
# 2. **Data Preparation**: Sequences for training the model are created.
# 3. **Model Building**: A neural network (LSTM) model is built and trained for each driver.
# 4. **Training the Model**: The model is trained on the training data.
# 5. **Evaluating the Model**: Model performance is evaluated on the race data.
# 6. **Results Visualization**: The training history and feature importance are visualized.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from keras.losses import Huber
from keras.metrics import MeanSquaredError, RootMeanSquaredError, MeanAbsolutePercentageError
import keras_tuner as kt

# Iterate over model objectives and drivers
for type_objective in model_parametr_objective:
    for driver in driver_list:

        # Load the training and race data for each driver
        train_data = pd.read_csv(f"/content/drive/MyDrive/F1_MODEL/with_points/2022_2024/DATA_BRAZIL_2024/train_data_scaled_points_{driver}.csv")
        race_data = pd.read_csv(f"/content/drive/MyDrive/F1_MODEL/with_points/2022_2024/DATA_BRAZIL_2024/race_data_scaled_points_{driver}.csv")

        # Prepare feature matrices (X) and target vectors (y)
        X_train_data = train_data.drop(['driver_id'], axis=1)
        y_train_data = train_data['LapTime_seconds']
        X_race_data = race_data.drop(['driver_id'], axis=1)
        y_race_data = race_data['LapTime_seconds']

        # Hyperparameter tuning using KerasTuner
        tuner = kt.Hyperband(
            build_model,
            objective=type_objective,
            max_epochs=30,
            factor=3,
            max_consecutive_failed_trials= 5,
            directory=f"/content/drive/MyDrive/F1_MODEL/with_points/models_v3/my_dir_{driver}_{type_objective}_points_huber",
            project_name='f1_lap_time_prediction_points'
        )

        # Set sequence length and create sequences for training
        SEQ_LENGTH = 3
        X_train_seq = create_sequences(X_train_data.values, SEQ_LENGTH)
        y_train_seq = create_sequences(y_train_data.values, SEQ_LENGTH)

        # Create mask to eliminate Nan data
        mask = ~np.isnan(X_train_seq).any(axis=(1, 2))
        X_train_seq = X_train_seq[mask]
        y_train_seq = y_train_seq[mask]

        # Search for the best hyperparameters
        tuner.search(X_train_seq, y_train_seq, epochs=30, validation_split=0.2)

        # Retrieve the best hyperparameters
        best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

        # Build the model using the best hyperparameters
        model = tuner.hypermodel.build(best_hps)

        # Train the model on training data
        history_train = model.fit(X_train_seq, y_train_seq, epochs=35, validation_split=0.2, batch_size=32)

        # Create sequences from race data using the best sequence length
        X_race_seq = create_sequences(X_race_data.values, best_hps.get('seq_length'))
        y_race_seq = create_sequences(y_race_data.values, best_hps.get('seq_length'))

        # Fine-tune the model on race data
        history_race = model.fit(X_race_seq, y_race_seq, validation_split=0.2, epochs=20, batch_size=32)

        # Append the training and race histories for analysis
        all_histories_train.append(history_train)
        all_histories_race.append(history_race)

        # Save model weights for future use
        weights = model.get_weights()[0]
        wage_weights.append(weights)

        # Base stats about model
        print(driver)
        print(f"Best seq: {best_hps.get('seq_length')}")
        print(f"Best number of layer LSTM: {best_hps.get('num_layers')}")
        for i in range(best_hps.get('num_layers')):
          print(f"Number of units in Dense {i+1}: {best_hps.get('units_' + str(i))}")
        print(f"Number of units in Dense: {best_hps.get('dense_units')}")
        print(f"Best optimizer: {best_hps.get('optimizer')}")

        model.save(f"/content/drive/MyDrive/F1_MODEL/with_points/2022_2024/model_v3/model_trained_with_best_hyperparams_and_race_data_{driver}_{type_objective}_points_huber.h5")
# Out:
# Reloading Tuner from /content/drive/MyDrive/F1_MODEL/with_points/models_v3/my_dir_VER_mean_squared_error_points_huber/f1_lap_time_prediction_points/tuner0.json
# Epoch 1/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.9082 - mae: 0.5709 - mean_absolute_percentage_error: 174.3470 - mean_squared_error: 0.5767 - root_mean_squared_error: 0.7523 - val_loss: 0.7683 - val_mae: 0.4107 - val_mean_absolute_percentage_error: 177.8433 - val_mean_squared_error: 0.3554 - val_root_mean_squared_error: 0.5961
# Epoch 2/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7440 - mae: 0.3937 - mean_absolute_percentage_error: 208.7079 - mean_squared_error: 0.3364 - root_mean_squared_error: 0.5799 - val_loss: 0.6980 - val_mae: 0.4066 - val_mean_absolute_percentage_error: 171.7620 - val_mean_squared_error: 0.3500 - val_root_mean_squared_error: 0.5916
# Epoch 3/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6712 - mae: 0.3843 - mean_absolute_percentage_error: 188.2943 - mean_squared_error: 0.3235 - root_mean_squared_error: 0.5685 - val_loss: 0.6349 - val_mae: 0.4043 - val_mean_absolute_percentage_error: 171.9370 - val_mean_squared_error: 0.3507 - val_root_mean_squared_error: 0.5922
# Epoch 4/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6078 - mae: 0.3813 - mean_absolute_percentage_error: 184.8587 - mean_squared_error: 0.3174 - root_mean_squared_error: 0.5632 - val_loss: 0.5778 - val_mae: 0.4074 - val_mean_absolute_percentage_error: 182.0770 - val_mean_squared_error: 0.3511 - val_root_mean_squared_error: 0.5925
# Epoch 5/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5540 - mae: 0.3887 - mean_absolute_percentage_error: 213.6978 - mean_squared_error: 0.3218 - root_mean_squared_error: 0.5671 - val_loss: 0.5248 - val_mae: 0.4035 - val_mean_absolute_percentage_error: 173.6833 - val_mean_squared_error: 0.3502 - val_root_mean_squared_error: 0.5918
# Epoch 6/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5020 - mae: 0.3831 - mean_absolute_percentage_error: 185.9948 - mean_squared_error: 0.3248 - root_mean_squared_error: 0.5699 - val_loss: 0.4778 - val_mae: 0.4008 - val_mean_absolute_percentage_error: 170.2742 - val_mean_squared_error: 0.3511 - val_root_mean_squared_error: 0.5925
# Epoch 7/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4565 - mae: 0.3817 - mean_absolute_percentage_error: 195.0272 - mean_squared_error: 0.3252 - root_mean_squared_error: 0.5702 - val_loss: 0.4370 - val_mae: 0.4147 - val_mean_absolute_percentage_error: 170.4052 - val_mean_squared_error: 0.3528 - val_root_mean_squared_error: 0.5940
# Epoch 8/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4172 - mae: 0.3882 - mean_absolute_percentage_error: 190.4235 - mean_squared_error: 0.3278 - root_mean_squared_error: 0.5724 - val_loss: 0.3973 - val_mae: 0.4022 - val_mean_absolute_percentage_error: 172.2183 - val_mean_squared_error: 0.3517 - val_root_mean_squared_error: 0.5931
# Epoch 9/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.3782 - mae: 0.3849 - mean_absolute_percentage_error: 201.5531 - mean_squared_error: 0.3243 - root_mean_squared_error: 0.5694 - val_loss: 0.3638 - val_mae: 0.4025 - val_mean_absolute_percentage_error: 171.3683 - val_mean_squared_error: 0.3524 - val_root_mean_squared_error: 0.5937
# Epoch 10/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.3400 - mae: 0.3718 - mean_absolute_percentage_error: 213.0607 - mean_squared_error: 0.3112 - root_mean_squared_error: 0.5578 - val_loss: 0.3332 - val_mae: 0.3978 - val_mean_absolute_percentage_error: 170.8243 - val_mean_squared_error: 0.3546 - val_root_mean_squared_error: 0.5955
# Epoch 11/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.3101 - mae: 0.3732 - mean_absolute_percentage_error: 179.6833 - mean_squared_error: 0.3098 - root_mean_squared_error: 0.5564 - val_loss: 0.3062 - val_mae: 0.3990 - val_mean_absolute_percentage_error: 169.2171 - val_mean_squared_error: 0.3530 - val_root_mean_squared_error: 0.5942
# Epoch 12/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2940 - mae: 0.3919 - mean_absolute_percentage_error: 196.2946 - mean_squared_error: 0.3337 - root_mean_squared_error: 0.5776 - val_loss: 0.2838 - val_mae: 0.3979 - val_mean_absolute_percentage_error: 164.6247 - val_mean_squared_error: 0.3595 - val_root_mean_squared_error: 0.5996
# Epoch 13/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2713 - mae: 0.3889 - mean_absolute_percentage_error: 210.5477 - mean_squared_error: 0.3388 - root_mean_squared_error: 0.5817 - val_loss: 0.2620 - val_mae: 0.3952 - val_mean_absolute_percentage_error: 170.9464 - val_mean_squared_error: 0.3563 - val_root_mean_squared_error: 0.5969
# Epoch 14/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2510 - mae: 0.3877 - mean_absolute_percentage_error: 199.6936 - mean_squared_error: 0.3426 - root_mean_squared_error: 0.5849 - val_loss: 0.2434 - val_mae: 0.3947 - val_mean_absolute_percentage_error: 174.2498 - val_mean_squared_error: 0.3539 - val_root_mean_squared_error: 0.5949
# Epoch 15/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2300 - mae: 0.3790 - mean_absolute_percentage_error: 184.5507 - mean_squared_error: 0.3311 - root_mean_squared_error: 0.5753 - val_loss: 0.2319 - val_mae: 0.4070 - val_mean_absolute_percentage_error: 157.6618 - val_mean_squared_error: 0.3667 - val_root_mean_squared_error: 0.6056
# Epoch 16/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2162 - mae: 0.3839 - mean_absolute_percentage_error: 197.9169 - mean_squared_error: 0.3372 - root_mean_squared_error: 0.5806 - val_loss: 0.2142 - val_mae: 0.3945 - val_mean_absolute_percentage_error: 163.7242 - val_mean_squared_error: 0.3563 - val_root_mean_squared_error: 0.5969
# Epoch 17/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1983 - mae: 0.3748 - mean_absolute_percentage_error: 185.8898 - mean_squared_error: 0.3221 - root_mean_squared_error: 0.5672 - val_loss: 0.2022 - val_mae: 0.3914 - val_mean_absolute_percentage_error: 172.5413 - val_mean_squared_error: 0.3563 - val_root_mean_squared_error: 0.5969
# Epoch 18/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1965 - mae: 0.3873 - mean_absolute_percentage_error: 206.1663 - mean_squared_error: 0.3519 - root_mean_squared_error: 0.5930 - val_loss: 0.1928 - val_mae: 0.3895 - val_mean_absolute_percentage_error: 171.5349 - val_mean_squared_error: 0.3585 - val_root_mean_squared_error: 0.5988
# Epoch 19/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1831 - mae: 0.3856 - mean_absolute_percentage_error: 202.4097 - mean_squared_error: 0.3357 - root_mean_squared_error: 0.5793 - val_loss: 0.1842 - val_mae: 0.3931 - val_mean_absolute_percentage_error: 172.5667 - val_mean_squared_error: 0.3575 - val_root_mean_squared_error: 0.5979
# Epoch 20/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1766 - mae: 0.3856 - mean_absolute_percentage_error: 192.8962 - mean_squared_error: 0.3415 - root_mean_squared_error: 0.5843 - val_loss: 0.1768 - val_mae: 0.3905 - val_mean_absolute_percentage_error: 176.8193 - val_mean_squared_error: 0.3562 - val_root_mean_squared_error: 0.5968
# Epoch 21/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1694 - mae: 0.3828 - mean_absolute_percentage_error: 203.9604 - mean_squared_error: 0.3408 - root_mean_squared_error: 0.5837 - val_loss: 0.1708 - val_mae: 0.3873 - val_mean_absolute_percentage_error: 163.7044 - val_mean_squared_error: 0.3582 - val_root_mean_squared_error: 0.5985
# Epoch 22/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1624 - mae: 0.3789 - mean_absolute_percentage_error: 203.6565 - mean_squared_error: 0.3378 - root_mean_squared_error: 0.5809 - val_loss: 0.1672 - val_mae: 0.3883 - val_mean_absolute_percentage_error: 164.1668 - val_mean_squared_error: 0.3637 - val_root_mean_squared_error: 0.6031
# Epoch 23/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1549 - mae: 0.3779 - mean_absolute_percentage_error: 221.9965 - mean_squared_error: 0.3253 - root_mean_squared_error: 0.5701 - val_loss: 0.1619 - val_mae: 0.3864 - val_mean_absolute_percentage_error: 172.9700 - val_mean_squared_error: 0.3578 - val_root_mean_squared_error: 0.5982
# Epoch 24/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1532 - mae: 0.3800 - mean_absolute_percentage_error: 186.0248 - mean_squared_error: 0.3367 - root_mean_squared_error: 0.5799 - val_loss: 0.1588 - val_mae: 0.3903 - val_mean_absolute_percentage_error: 168.0271 - val_mean_squared_error: 0.3578 - val_root_mean_squared_error: 0.5981
# Epoch 25/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1519 - mae: 0.3804 - mean_absolute_percentage_error: 165.9510 - mean_squared_error: 0.3392 - root_mean_squared_error: 0.5823 - val_loss: 0.1558 - val_mae: 0.3878 - val_mean_absolute_percentage_error: 167.8266 - val_mean_squared_error: 0.3593 - val_root_mean_squared_error: 0.5994
# Epoch 26/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1518 - mae: 0.3891 - mean_absolute_percentage_error: 190.0067 - mean_squared_error: 0.3494 - root_mean_squared_error: 0.5909 - val_loss: 0.1547 - val_mae: 0.3954 - val_mean_absolute_percentage_error: 155.4702 - val_mean_squared_error: 0.3608 - val_root_mean_squared_error: 0.6007
# Epoch 27/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1450 - mae: 0.3802 - mean_absolute_percentage_error: 187.3319 - mean_squared_error: 0.3332 - root_mean_squared_error: 0.5772 - val_loss: 0.1528 - val_mae: 0.3860 - val_mean_absolute_percentage_error: 156.5622 - val_mean_squared_error: 0.3619 - val_root_mean_squared_error: 0.6016
# Epoch 28/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1441 - mae: 0.3720 - mean_absolute_percentage_error: 204.0994 - mean_squared_error: 0.3403 - root_mean_squared_error: 0.5832 - val_loss: 0.1509 - val_mae: 0.3902 - val_mean_absolute_percentage_error: 157.0282 - val_mean_squared_error: 0.3600 - val_root_mean_squared_error: 0.6000
# Epoch 29/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1424 - mae: 0.3729 - mean_absolute_percentage_error: 205.9507 - mean_squared_error: 0.3370 - root_mean_squared_error: 0.5803 - val_loss: 0.1495 - val_mae: 0.3816 - val_mean_absolute_percentage_error: 163.7023 - val_mean_squared_error: 0.3629 - val_root_mean_squared_error: 0.6024
# Epoch 30/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1416 - mae: 0.3667 - mean_absolute_percentage_error: 181.2509 - mean_squared_error: 0.3382 - root_mean_squared_error: 0.5815 - val_loss: 0.1487 - val_mae: 0.3820 - val_mean_absolute_percentage_error: 159.8971 - val_mean_squared_error: 0.3628 - val_root_mean_squared_error: 0.6023
# Epoch 31/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1402 - mae: 0.3695 - mean_absolute_percentage_error: 182.7986 - mean_squared_error: 0.3417 - root_mean_squared_error: 0.5843 - val_loss: 0.1480 - val_mae: 0.3855 - val_mean_absolute_percentage_error: 159.6176 - val_mean_squared_error: 0.3606 - val_root_mean_squared_error: 0.6005
# Epoch 32/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1365 - mae: 0.3629 - mean_absolute_percentage_error: 182.3332 - mean_squared_error: 0.3274 - root_mean_squared_error: 0.5719 - val_loss: 0.1478 - val_mae: 0.3830 - val_mean_absolute_percentage_error: 160.5062 - val_mean_squared_error: 0.3649 - val_root_mean_squared_error: 0.6041
# Epoch 33/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1336 - mae: 0.3580 - mean_absolute_percentage_error: 215.5966 - mean_squared_error: 0.3204 - root_mean_squared_error: 0.5654 - val_loss: 0.1477 - val_mae: 0.3816 - val_mean_absolute_percentage_error: 152.4068 - val_mean_squared_error: 0.3651 - val_root_mean_squared_error: 0.6042
# Epoch 34/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1400 - mae: 0.3771 - mean_absolute_percentage_error: 196.4455 - mean_squared_error: 0.3330 - root_mean_squared_error: 0.5769 - val_loss: 0.1478 - val_mae: 0.3837 - val_mean_absolute_percentage_error: 160.9599 - val_mean_squared_error: 0.3669 - val_root_mean_squared_error: 0.6057
# Epoch 35/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1404 - mae: 0.3748 - mean_absolute_percentage_error: 186.3729 - mean_squared_error: 0.3395 - root_mean_squared_error: 0.5825 - val_loss: 0.1477 - val_mae: 0.3841 - val_mean_absolute_percentage_error: 158.5112 - val_mean_squared_error: 0.3678 - val_root_mean_squared_error: 0.6065
# Epoch 1/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0136 - mae: 0.0725 - mean_absolute_percentage_error: 68.3032 - mean_squared_error: 0.0257 - root_mean_squared_error: 0.1601 - val_loss: 0.0114 - val_mae: 0.0521 - val_mean_absolute_percentage_error: 394.3387 - val_mean_squared_error: 0.0223 - val_root_mean_squared_error: 0.1493
# Epoch 2/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0127 - mae: 0.0619 - mean_absolute_percentage_error: 29.4567 - mean_squared_error: 0.0246 - root_mean_squared_error: 0.1567 - val_loss: 0.0112 - val_mae: 0.0508 - val_mean_absolute_percentage_error: 427.6029 - val_mean_squared_error: 0.0222 - val_root_mean_squared_error: 0.1489
# Epoch 3/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0107 - mae: 0.0550 - mean_absolute_percentage_error: 37.1770 - mean_squared_error: 0.0202 - root_mean_squared_error: 0.1416 - val_loss: 0.0111 - val_mae: 0.0533 - val_mean_absolute_percentage_error: 419.9401 - val_mean_squared_error: 0.0223 - val_root_mean_squared_error: 0.1494
# Epoch 4/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0111 - mae: 0.0564 - mean_absolute_percentage_error: 42.6837 - mean_squared_error: 0.0212 - root_mean_squared_error: 0.1445 - val_loss: 0.0110 - val_mae: 0.0517 - val_mean_absolute_percentage_error: 431.4892 - val_mean_squared_error: 0.0223 - val_root_mean_squared_error: 0.1492
# Epoch 5/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0100 - mae: 0.0526 - mean_absolute_percentage_error: 37.8179 - mean_squared_error: 0.0197 - root_mean_squared_error: 0.1395 - val_loss: 0.0111 - val_mae: 0.0556 - val_mean_absolute_percentage_error: 442.1162 - val_mean_squared_error: 0.0225 - val_root_mean_squared_error: 0.1500
# Epoch 6/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0138 - mae: 0.0612 - mean_absolute_percentage_error: 48.0602 - mean_squared_error: 0.0287 - root_mean_squared_error: 0.1689 - val_loss: 0.0112 - val_mae: 0.0615 - val_mean_absolute_percentage_error: 424.0788 - val_mean_squared_error: 0.0231 - val_root_mean_squared_error: 0.1519
# Epoch 7/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0101 - mae: 0.0549 - mean_absolute_percentage_error: 37.8195 - mean_squared_error: 0.0190 - root_mean_squared_error: 0.1376 - val_loss: 0.0107 - val_mae: 0.0493 - val_mean_absolute_percentage_error: 448.8963 - val_mean_squared_error: 0.0221 - val_root_mean_squared_error: 0.1488
# Epoch 8/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0113 - mae: 0.0547 - mean_absolute_percentage_error: 45.9713 - mean_squared_error: 0.0235 - root_mean_squared_error: 0.1527 - val_loss: 0.0107 - val_mae: 0.0504 - val_mean_absolute_percentage_error: 428.3506 - val_mean_squared_error: 0.0221 - val_root_mean_squared_error: 0.1488
# Epoch 9/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0136 - mae: 0.0591 - mean_absolute_percentage_error: 27.4430 - mean_squared_error: 0.0289 - root_mean_squared_error: 0.1689 - val_loss: 0.0107 - val_mae: 0.0513 - val_mean_absolute_percentage_error: 441.9317 - val_mean_squared_error: 0.0222 - val_root_mean_squared_error: 0.1492
# Epoch 10/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0105 - mae: 0.0535 - mean_absolute_percentage_error: 56.6226 - mean_squared_error: 0.0209 - root_mean_squared_error: 0.1440 - val_loss: 0.0105 - val_mae: 0.0489 - val_mean_absolute_percentage_error: 434.2833 - val_mean_squared_error: 0.0220 - val_root_mean_squared_error: 0.1484
# Epoch 11/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0111 - mae: 0.0539 - mean_absolute_percentage_error: 32.9837 - mean_squared_error: 0.0234 - root_mean_squared_error: 0.1520 - val_loss: 0.0106 - val_mae: 0.0528 - val_mean_absolute_percentage_error: 420.6980 - val_mean_squared_error: 0.0223 - val_root_mean_squared_error: 0.1495
# Epoch 12/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0108 - mae: 0.0529 - mean_absolute_percentage_error: 50.6209 - mean_squared_error: 0.0229 - root_mean_squared_error: 0.1509 - val_loss: 0.0105 - val_mae: 0.0514 - val_mean_absolute_percentage_error: 423.4564 - val_mean_squared_error: 0.0222 - val_root_mean_squared_error: 0.1489
# Epoch 13/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0104 - mae: 0.0546 - mean_absolute_percentage_error: 34.4003 - mean_squared_error: 0.0214 - root_mean_squared_error: 0.1459 - val_loss: 0.0106 - val_mae: 0.0537 - val_mean_absolute_percentage_error: 428.7993 - val_mean_squared_error: 0.0224 - val_root_mean_squared_error: 0.1497
# Epoch 14/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0111 - mae: 0.0555 - mean_absolute_percentage_error: 42.8781 - mean_squared_error: 0.0229 - root_mean_squared_error: 0.1506 - val_loss: 0.0106 - val_mae: 0.0533 - val_mean_absolute_percentage_error: 430.2310 - val_mean_squared_error: 0.0223 - val_root_mean_squared_error: 0.1495
# Epoch 15/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0111 - mae: 0.0591 - mean_absolute_percentage_error: 51.3109 - mean_squared_error: 0.0227 - root_mean_squared_error: 0.1504 - val_loss: 0.0104 - val_mae: 0.0494 - val_mean_absolute_percentage_error: 431.1491 - val_mean_squared_error: 0.0221 - val_root_mean_squared_error: 0.1486
# Epoch 16/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0112 - mae: 0.0574 - mean_absolute_percentage_error: 41.2342 - mean_squared_error: 0.0238 - root_mean_squared_error: 0.1537 - val_loss: 0.0106 - val_mae: 0.0568 - val_mean_absolute_percentage_error: 426.6439 - val_mean_squared_error: 0.0225 - val_root_mean_squared_error: 0.1501
# Epoch 17/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0110 - mae: 0.0555 - mean_absolute_percentage_error: 31.6068 - mean_squared_error: 0.0226 - root_mean_squared_error: 0.1499 - val_loss: 0.0104 - val_mae: 0.0519 - val_mean_absolute_percentage_error: 418.7151 - val_mean_squared_error: 0.0222 - val_root_mean_squared_error: 0.1490
# Epoch 18/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0110 - mae: 0.0560 - mean_absolute_percentage_error: 28.6878 - mean_squared_error: 0.0228 - root_mean_squared_error: 0.1507 - val_loss: 0.0104 - val_mae: 0.0530 - val_mean_absolute_percentage_error: 436.3466 - val_mean_squared_error: 0.0222 - val_root_mean_squared_error: 0.1491
# Epoch 19/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0104 - mae: 0.0540 - mean_absolute_percentage_error: 50.6267 - mean_squared_error: 0.0217 - root_mean_squared_error: 0.1466 - val_loss: 0.0104 - val_mae: 0.0523 - val_mean_absolute_percentage_error: 430.3452 - val_mean_squared_error: 0.0222 - val_root_mean_squared_error: 0.1491
# Epoch 20/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0107 - mae: 0.0559 - mean_absolute_percentage_error: 34.2845 - mean_squared_error: 0.0226 - root_mean_squared_error: 0.1498 - val_loss: 0.0104 - val_mae: 0.0536 - val_mean_absolute_percentage_error: 417.3279 - val_mean_squared_error: 0.0223 - val_root_mean_squared_error: 0.1493
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# VER
# Best seq: 3
# Best number of layer LSTM: 1
# Number of units in Dense 1: 96
# Number of units in Dense: 160
# Best optimizer: adam
# Reloading Tuner from /content/drive/MyDrive/F1_MODEL/with_points/models_v3/my_dir_NOR_mean_squared_error_points_huber/f1_lap_time_prediction_points/tuner0.json
# Epoch 1/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 1.0703 - mae: 0.8899 - mean_absolute_percentage_error: 101.8608 - mean_squared_error: 1.2525 - root_mean_squared_error: 1.1189 - val_loss: 0.9875 - val_mae: 0.9010 - val_mean_absolute_percentage_error: 102.7913 - val_mean_squared_error: 1.1711 - val_root_mean_squared_error: 1.0822
# Epoch 2/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.8637 - mae: 0.7790 - mean_absolute_percentage_error: 130.4536 - mean_squared_error: 0.9180 - root_mean_squared_error: 0.9568 - val_loss: 0.7685 - val_mae: 0.7494 - val_mean_absolute_percentage_error: 101.2584 - val_mean_squared_error: 0.7966 - val_root_mean_squared_error: 0.8925
# Epoch 3/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.6245 - mae: 0.5593 - mean_absolute_percentage_error: 165.4246 - mean_squared_error: 0.5529 - root_mean_squared_error: 0.7433 - val_loss: 0.6433 - val_mae: 0.6776 - val_mean_absolute_percentage_error: 102.9296 - val_mean_squared_error: 0.6593 - val_root_mean_squared_error: 0.8120
# Epoch 4/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.5374 - mae: 0.5175 - mean_absolute_percentage_error: 195.5151 - mean_squared_error: 0.4994 - root_mean_squared_error: 0.7064 - val_loss: 0.5700 - val_mae: 0.6492 - val_mean_absolute_percentage_error: 103.7452 - val_mean_squared_error: 0.6139 - val_root_mean_squared_error: 0.7835
# Epoch 5/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4738 - mae: 0.4900 - mean_absolute_percentage_error: 160.0403 - mean_squared_error: 0.4492 - root_mean_squared_error: 0.6695 - val_loss: 0.5134 - val_mae: 0.6252 - val_mean_absolute_percentage_error: 103.7803 - val_mean_squared_error: 0.5800 - val_root_mean_squared_error: 0.7616
# Epoch 6/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4249 - mae: 0.4697 - mean_absolute_percentage_error: 176.3570 - mean_squared_error: 0.4090 - root_mean_squared_error: 0.6394 - val_loss: 0.4676 - val_mae: 0.6039 - val_mean_absolute_percentage_error: 104.2245 - val_mean_squared_error: 0.5537 - val_root_mean_squared_error: 0.7441
# Epoch 7/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3899 - mae: 0.4601 - mean_absolute_percentage_error: 186.8066 - mean_squared_error: 0.4022 - root_mean_squared_error: 0.6341 - val_loss: 0.4347 - val_mae: 0.5963 - val_mean_absolute_percentage_error: 104.0969 - val_mean_squared_error: 0.5400 - val_root_mean_squared_error: 0.7348
# Epoch 8/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.3595 - mae: 0.4504 - mean_absolute_percentage_error: 167.6671 - mean_squared_error: 0.3905 - root_mean_squared_error: 0.6247 - val_loss: 0.4068 - val_mae: 0.5848 - val_mean_absolute_percentage_error: 104.1967 - val_mean_squared_error: 0.5278 - val_root_mean_squared_error: 0.7265
# Epoch 9/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 0.3366 - mae: 0.4444 - mean_absolute_percentage_error: 237.4969 - mean_squared_error: 0.3870 - root_mean_squared_error: 0.6220 - val_loss: 0.3822 - val_mae: 0.5727 - val_mean_absolute_percentage_error: 103.9519 - val_mean_squared_error: 0.5138 - val_root_mean_squared_error: 0.7168
# Epoch 10/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.3181 - mae: 0.4414 - mean_absolute_percentage_error: 182.9019 - mean_squared_error: 0.3851 - root_mean_squared_error: 0.6205 - val_loss: 0.3629 - val_mae: 0.5626 - val_mean_absolute_percentage_error: 104.5281 - val_mean_squared_error: 0.5036 - val_root_mean_squared_error: 0.7096
# Epoch 11/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2974 - mae: 0.4301 - mean_absolute_percentage_error: 187.3375 - mean_squared_error: 0.3692 - root_mean_squared_error: 0.6074 - val_loss: 0.3475 - val_mae: 0.5582 - val_mean_absolute_percentage_error: 104.6836 - val_mean_squared_error: 0.4958 - val_root_mean_squared_error: 0.7041
# Epoch 12/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2862 - mae: 0.4287 - mean_absolute_percentage_error: 171.9937 - mean_squared_error: 0.3696 - root_mean_squared_error: 0.6078 - val_loss: 0.3336 - val_mae: 0.5513 - val_mean_absolute_percentage_error: 105.2863 - val_mean_squared_error: 0.4874 - val_root_mean_squared_error: 0.6982
# Epoch 13/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2764 - mae: 0.4274 - mean_absolute_percentage_error: 209.2269 - mean_squared_error: 0.3838 - root_mean_squared_error: 0.6192 - val_loss: 0.3214 - val_mae: 0.5435 - val_mean_absolute_percentage_error: 105.2840 - val_mean_squared_error: 0.4795 - val_root_mean_squared_error: 0.6925
# Epoch 14/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2677 - mae: 0.4276 - mean_absolute_percentage_error: 178.8503 - mean_squared_error: 0.3692 - root_mean_squared_error: 0.6074 - val_loss: 0.3134 - val_mae: 0.5427 - val_mean_absolute_percentage_error: 105.6869 - val_mean_squared_error: 0.4779 - val_root_mean_squared_error: 0.6913
# Epoch 15/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2549 - mae: 0.4152 - mean_absolute_percentage_error: 197.3443 - mean_squared_error: 0.3543 - root_mean_squared_error: 0.5950 - val_loss: 0.3062 - val_mae: 0.5407 - val_mean_absolute_percentage_error: 105.5245 - val_mean_squared_error: 0.4766 - val_root_mean_squared_error: 0.6904
# Epoch 16/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2583 - mae: 0.4308 - mean_absolute_percentage_error: 224.9719 - mean_squared_error: 0.3951 - root_mean_squared_error: 0.6270 - val_loss: 0.2975 - val_mae: 0.5359 - val_mean_absolute_percentage_error: 106.3241 - val_mean_squared_error: 0.4690 - val_root_mean_squared_error: 0.6848
# Epoch 17/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2506 - mae: 0.4257 - mean_absolute_percentage_error: 203.4319 - mean_squared_error: 0.3719 - root_mean_squared_error: 0.6097 - val_loss: 0.2927 - val_mae: 0.5376 - val_mean_absolute_percentage_error: 106.0421 - val_mean_squared_error: 0.4691 - val_root_mean_squared_error: 0.6849
# Epoch 18/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2481 - mae: 0.4292 - mean_absolute_percentage_error: 175.1995 - mean_squared_error: 0.3771 - root_mean_squared_error: 0.6139 - val_loss: 0.2863 - val_mae: 0.5342 - val_mean_absolute_percentage_error: 106.5424 - val_mean_squared_error: 0.4644 - val_root_mean_squared_error: 0.6815
# Epoch 19/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2306 - mae: 0.4072 - mean_absolute_percentage_error: 181.8471 - mean_squared_error: 0.3468 - root_mean_squared_error: 0.5888 - val_loss: 0.2795 - val_mae: 0.5273 - val_mean_absolute_percentage_error: 106.9670 - val_mean_squared_error: 0.4583 - val_root_mean_squared_error: 0.6770
# Epoch 20/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2376 - mae: 0.4251 - mean_absolute_percentage_error: 208.7818 - mean_squared_error: 0.3713 - root_mean_squared_error: 0.6091 - val_loss: 0.2738 - val_mae: 0.5239 - val_mean_absolute_percentage_error: 107.8078 - val_mean_squared_error: 0.4530 - val_root_mean_squared_error: 0.6731
# Epoch 21/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.2308 - mae: 0.4228 - mean_absolute_percentage_error: 198.8146 - mean_squared_error: 0.3613 - root_mean_squared_error: 0.6009 - val_loss: 0.2714 - val_mae: 0.5247 - val_mean_absolute_percentage_error: 107.3436 - val_mean_squared_error: 0.4551 - val_root_mean_squared_error: 0.6746
# Epoch 22/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2247 - mae: 0.4125 - mean_absolute_percentage_error: 205.3736 - mean_squared_error: 0.3611 - root_mean_squared_error: 0.6008 - val_loss: 0.2649 - val_mae: 0.5175 - val_mean_absolute_percentage_error: 108.4810 - val_mean_squared_error: 0.4465 - val_root_mean_squared_error: 0.6682
# Epoch 23/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2332 - mae: 0.4315 - mean_absolute_percentage_error: 193.3468 - mean_squared_error: 0.3856 - root_mean_squared_error: 0.6207 - val_loss: 0.2625 - val_mae: 0.5178 - val_mean_absolute_percentage_error: 108.5472 - val_mean_squared_error: 0.4472 - val_root_mean_squared_error: 0.6688
# Epoch 24/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2209 - mae: 0.4151 - mean_absolute_percentage_error: 171.4405 - mean_squared_error: 0.3776 - root_mean_squared_error: 0.6131 - val_loss: 0.2596 - val_mae: 0.5160 - val_mean_absolute_percentage_error: 108.7231 - val_mean_squared_error: 0.4463 - val_root_mean_squared_error: 0.6681
# Epoch 25/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2170 - mae: 0.4114 - mean_absolute_percentage_error: 184.3272 - mean_squared_error: 0.3588 - root_mean_squared_error: 0.5990 - val_loss: 0.2551 - val_mae: 0.5133 - val_mean_absolute_percentage_error: 108.9291 - val_mean_squared_error: 0.4412 - val_root_mean_squared_error: 0.6642
# Epoch 26/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2153 - mae: 0.4168 - mean_absolute_percentage_error: 178.7121 - mean_squared_error: 0.3582 - root_mean_squared_error: 0.5984 - val_loss: 0.2550 - val_mae: 0.5187 - val_mean_absolute_percentage_error: 109.1256 - val_mean_squared_error: 0.4454 - val_root_mean_squared_error: 0.6674
# Epoch 27/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2132 - mae: 0.4135 - mean_absolute_percentage_error: 172.7531 - mean_squared_error: 0.3583 - root_mean_squared_error: 0.5985 - val_loss: 0.2500 - val_mae: 0.5105 - val_mean_absolute_percentage_error: 109.1883 - val_mean_squared_error: 0.4387 - val_root_mean_squared_error: 0.6624
# Epoch 28/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2145 - mae: 0.4171 - mean_absolute_percentage_error: 182.8799 - mean_squared_error: 0.3715 - root_mean_squared_error: 0.6094 - val_loss: 0.2480 - val_mae: 0.5100 - val_mean_absolute_percentage_error: 109.4931 - val_mean_squared_error: 0.4386 - val_root_mean_squared_error: 0.6622
# Epoch 29/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2067 - mae: 0.4118 - mean_absolute_percentage_error: 174.8020 - mean_squared_error: 0.3526 - root_mean_squared_error: 0.5930 - val_loss: 0.2428 - val_mae: 0.5028 - val_mean_absolute_percentage_error: 110.4835 - val_mean_squared_error: 0.4304 - val_root_mean_squared_error: 0.6561
# Epoch 30/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2116 - mae: 0.4209 - mean_absolute_percentage_error: 213.0565 - mean_squared_error: 0.3676 - root_mean_squared_error: 0.6063 - val_loss: 0.2437 - val_mae: 0.5087 - val_mean_absolute_percentage_error: 110.2121 - val_mean_squared_error: 0.4361 - val_root_mean_squared_error: 0.6604
# Epoch 31/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2041 - mae: 0.4138 - mean_absolute_percentage_error: 197.7382 - mean_squared_error: 0.3524 - root_mean_squared_error: 0.5936 - val_loss: 0.2389 - val_mae: 0.5036 - val_mean_absolute_percentage_error: 111.5017 - val_mean_squared_error: 0.4283 - val_root_mean_squared_error: 0.6545
# Epoch 32/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.1988 - mae: 0.3996 - mean_absolute_percentage_error: 216.8446 - mean_squared_error: 0.3471 - root_mean_squared_error: 0.5888 - val_loss: 0.2386 - val_mae: 0.5025 - val_mean_absolute_percentage_error: 110.6083 - val_mean_squared_error: 0.4315 - val_root_mean_squared_error: 0.6569
# Epoch 33/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.2056 - mae: 0.4139 - mean_absolute_percentage_error: 170.5807 - mean_squared_error: 0.3661 - root_mean_squared_error: 0.6049 - val_loss: 0.2374 - val_mae: 0.5043 - val_mean_absolute_percentage_error: 110.8104 - val_mean_squared_error: 0.4319 - val_root_mean_squared_error: 0.6572
# Epoch 34/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2016 - mae: 0.4114 - mean_absolute_percentage_error: 210.2975 - mean_squared_error: 0.3580 - root_mean_squared_error: 0.5983 - val_loss: 0.2316 - val_mae: 0.4949 - val_mean_absolute_percentage_error: 112.3896 - val_mean_squared_error: 0.4213 - val_root_mean_squared_error: 0.6491
# Epoch 35/35
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1976 - mae: 0.4074 - mean_absolute_percentage_error: 202.1571 - mean_squared_error: 0.3511 - root_mean_squared_error: 0.5924 - val_loss: 0.2315 - val_mae: 0.4977 - val_mean_absolute_percentage_error: 112.0815 - val_mean_squared_error: 0.4239 - val_root_mean_squared_error: 0.6511
# Epoch 1/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0754 - mae: 0.1923 - mean_absolute_percentage_error: 103.5796 - mean_squared_error: 0.0897 - root_mean_squared_error: 0.2954 - val_loss: 0.1258 - val_mae: 0.3663 - val_mean_absolute_percentage_error: 68.4479 - val_mean_squared_error: 0.1898 - val_root_mean_squared_error: 0.4356
# Epoch 2/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0498 - mae: 0.1022 - mean_absolute_percentage_error: 70.4319 - mean_squared_error: 0.0398 - root_mean_squared_error: 0.1992 - val_loss: 0.1180 - val_mae: 0.3515 - val_mean_absolute_percentage_error: 66.5195 - val_mean_squared_error: 0.1769 - val_root_mean_squared_error: 0.4206
# Epoch 3/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.0480 - mae: 0.0979 - mean_absolute_percentage_error: 79.5301 - mean_squared_error: 0.0397 - root_mean_squared_error: 0.1990 - val_loss: 0.1126 - val_mae: 0.3413 - val_mean_absolute_percentage_error: 65.0496 - val_mean_squared_error: 0.1688 - val_root_mean_squared_error: 0.4108
# Epoch 4/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0444 - mae: 0.0901 - mean_absolute_percentage_error: 80.2601 - mean_squared_error: 0.0341 - root_mean_squared_error: 0.1842 - val_loss: 0.1107 - val_mae: 0.3414 - val_mean_absolute_percentage_error: 64.6772 - val_mean_squared_error: 0.1673 - val_root_mean_squared_error: 0.4091
# Epoch 5/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0449 - mae: 0.0939 - mean_absolute_percentage_error: 71.9986 - mean_squared_error: 0.0378 - root_mean_squared_error: 0.1942 - val_loss: 0.1079 - val_mae: 0.3371 - val_mean_absolute_percentage_error: 63.7836 - val_mean_squared_error: 0.1642 - val_root_mean_squared_error: 0.4052
# Epoch 6/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0446 - mae: 0.0923 - mean_absolute_percentage_error: 63.3224 - mean_squared_error: 0.0401 - root_mean_squared_error: 0.1993 - val_loss: 0.1042 - val_mae: 0.3316 - val_mean_absolute_percentage_error: 62.9839 - val_mean_squared_error: 0.1588 - val_root_mean_squared_error: 0.3985
# Epoch 7/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0429 - mae: 0.0924 - mean_absolute_percentage_error: 74.3682 - mean_squared_error: 0.0383 - root_mean_squared_error: 0.1948 - val_loss: 0.1011 - val_mae: 0.3249 - val_mean_absolute_percentage_error: 62.0115 - val_mean_squared_error: 0.1547 - val_root_mean_squared_error: 0.3933
# Epoch 8/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.0395 - mae: 0.0857 - mean_absolute_percentage_error: 72.5301 - mean_squared_error: 0.0328 - root_mean_squared_error: 0.1800 - val_loss: 0.0977 - val_mae: 0.3193 - val_mean_absolute_percentage_error: 61.4762 - val_mean_squared_error: 0.1499 - val_root_mean_squared_error: 0.3872
# Epoch 9/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0412 - mae: 0.0910 - mean_absolute_percentage_error: 76.8668 - mean_squared_error: 0.0387 - root_mean_squared_error: 0.1963 - val_loss: 0.0948 - val_mae: 0.3106 - val_mean_absolute_percentage_error: 60.3078 - val_mean_squared_error: 0.1460 - val_root_mean_squared_error: 0.3821
# Epoch 10/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0396 - mae: 0.0878 - mean_absolute_percentage_error: 68.3675 - mean_squared_error: 0.0368 - root_mean_squared_error: 0.1914 - val_loss: 0.0926 - val_mae: 0.3102 - val_mean_absolute_percentage_error: 60.3279 - val_mean_squared_error: 0.1435 - val_root_mean_squared_error: 0.3789
# Epoch 11/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0378 - mae: 0.0863 - mean_absolute_percentage_error: 91.9577 - mean_squared_error: 0.0350 - root_mean_squared_error: 0.1867 - val_loss: 0.0887 - val_mae: 0.3018 - val_mean_absolute_percentage_error: 59.6324 - val_mean_squared_error: 0.1375 - val_root_mean_squared_error: 0.3708
# Epoch 12/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0388 - mae: 0.0876 - mean_absolute_percentage_error: 70.1030 - mean_squared_error: 0.0393 - root_mean_squared_error: 0.1981 - val_loss: 0.0876 - val_mae: 0.3012 - val_mean_absolute_percentage_error: 59.3944 - val_mean_squared_error: 0.1369 - val_root_mean_squared_error: 0.3700
# Epoch 13/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0347 - mae: 0.0809 - mean_absolute_percentage_error: 67.7150 - mean_squared_error: 0.0323 - root_mean_squared_error: 0.1797 - val_loss: 0.0840 - val_mae: 0.2928 - val_mean_absolute_percentage_error: 58.7773 - val_mean_squared_error: 0.1314 - val_root_mean_squared_error: 0.3625
# Epoch 14/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0344 - mae: 0.0813 - mean_absolute_percentage_error: 65.4201 - mean_squared_error: 0.0333 - root_mean_squared_error: 0.1821 - val_loss: 0.0826 - val_mae: 0.2916 - val_mean_absolute_percentage_error: 58.3557 - val_mean_squared_error: 0.1301 - val_root_mean_squared_error: 0.3607
# Epoch 15/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0352 - mae: 0.0831 - mean_absolute_percentage_error: 54.1273 - mean_squared_error: 0.0368 - root_mean_squared_error: 0.1911 - val_loss: 0.0800 - val_mae: 0.2846 - val_mean_absolute_percentage_error: 57.9254 - val_mean_squared_error: 0.1264 - val_root_mean_squared_error: 0.3555
# Epoch 16/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.0352 - mae: 0.0842 - mean_absolute_percentage_error: 86.2873 - mean_squared_error: 0.0383 - root_mean_squared_error: 0.1946 - val_loss: 0.0765 - val_mae: 0.2773 - val_mean_absolute_percentage_error: 57.2558 - val_mean_squared_error: 0.1208 - val_root_mean_squared_error: 0.3476
# Epoch 17/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0326 - mae: 0.0813 - mean_absolute_percentage_error: 69.3083 - mean_squared_error: 0.0343 - root_mean_squared_error: 0.1847 - val_loss: 0.0756 - val_mae: 0.2763 - val_mean_absolute_percentage_error: 57.4348 - val_mean_squared_error: 0.1205 - val_root_mean_squared_error: 0.3472
# Epoch 18/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0308 - mae: 0.0782 - mean_absolute_percentage_error: 83.5469 - mean_squared_error: 0.0321 - root_mean_squared_error: 0.1785 - val_loss: 0.0725 - val_mae: 0.2675 - val_mean_absolute_percentage_error: 56.5078 - val_mean_squared_error: 0.1155 - val_root_mean_squared_error: 0.3399
# Epoch 19/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0301 - mae: 0.0788 - mean_absolute_percentage_error: 69.3611 - mean_squared_error: 0.0319 - root_mean_squared_error: 0.1780 - val_loss: 0.0702 - val_mae: 0.2650 - val_mean_absolute_percentage_error: 56.3848 - val_mean_squared_error: 0.1122 - val_root_mean_squared_error: 0.3350
# Epoch 20/20
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0312 - mae: 0.0803 - mean_absolute_percentage_error: 64.0451 - mean_squared_error: 0.0360 - root_mean_squared_error: 0.1888 - val_loss: 0.0687 - val_mae: 0.2610 - val_mean_absolute_percentage_error: 56.1448 - val_mean_squared_error: 0.1104 - val_root_mean_squared_error: 0.3323
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# NOR
# Best seq: 5
# Best number of layer LSTM: 1
# Number of units in Dense 1: 192
# Number of units in Dense: 96
# Best optimizer: adam
# Reloading Tuner from /content/drive/MyDrive/F1_MODEL/with_points/models_v3/my_dir_PER_mean_squared_error_points_huber/f1_lap_time_prediction_points/tuner0.json
# Epoch 1/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 1.2675 - mae: 0.6444 - mean_absolute_percentage_error: 291.4428 - mean_squared_error: 0.7594 - root_mean_squared_error: 0.8619 - val_loss: 0.6327 - val_mae: 0.5016 - val_mean_absolute_percentage_error: 146.3286 - val_mean_squared_error: 0.4788 - val_root_mean_squared_error: 0.6919
# Epoch 2/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5232 - mae: 0.4678 - mean_absolute_percentage_error: 353.6195 - mean_squared_error: 0.4552 - root_mean_squared_error: 0.6745 - val_loss: 0.3397 - val_mae: 0.4979 - val_mean_absolute_percentage_error: 145.7391 - val_mean_squared_error: 0.4740 - val_root_mean_squared_error: 0.6885
# Epoch 3/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2987 - mae: 0.4656 - mean_absolute_percentage_error: 441.5531 - mean_squared_error: 0.4486 - root_mean_squared_error: 0.6696 - val_loss: 0.2544 - val_mae: 0.4869 - val_mean_absolute_percentage_error: 154.1826 - val_mean_squared_error: 0.4709 - val_root_mean_squared_error: 0.6862
# Epoch 4/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2382 - mae: 0.4632 - mean_absolute_percentage_error: 309.1874 - mean_squared_error: 0.4529 - root_mean_squared_error: 0.6727 - val_loss: 0.2333 - val_mae: 0.4861 - val_mean_absolute_percentage_error: 147.2184 - val_mean_squared_error: 0.4722 - val_root_mean_squared_error: 0.6872
# Epoch 5/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.2163 - mae: 0.4557 - mean_absolute_percentage_error: 283.8322 - mean_squared_error: 0.4403 - root_mean_squared_error: 0.6635 - val_loss: 0.2287 - val_mae: 0.4897 - val_mean_absolute_percentage_error: 142.2603 - val_mean_squared_error: 0.4732 - val_root_mean_squared_error: 0.6879
# Epoch 6/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2233 - mae: 0.4717 - mean_absolute_percentage_error: 279.4852 - mean_squared_error: 0.4671 - root_mean_squared_error: 0.6832 - val_loss: 0.2257 - val_mae: 0.4849 - val_mean_absolute_percentage_error: 150.9304 - val_mean_squared_error: 0.4710 - val_root_mean_squared_error: 0.6863
# Epoch 7/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2167 - mae: 0.4624 - mean_absolute_percentage_error: 318.3399 - mean_squared_error: 0.4557 - root_mean_squared_error: 0.6749 - val_loss: 0.2242 - val_mae: 0.4807 - val_mean_absolute_percentage_error: 148.1062 - val_mean_squared_error: 0.4704 - val_root_mean_squared_error: 0.6859
# Epoch 8/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2145 - mae: 0.4664 - mean_absolute_percentage_error: 315.2952 - mean_squared_error: 0.4489 - root_mean_squared_error: 0.6699 - val_loss: 0.2242 - val_mae: 0.4839 - val_mean_absolute_percentage_error: 138.9842 - val_mean_squared_error: 0.4697 - val_root_mean_squared_error: 0.6853
# Epoch 9/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2140 - mae: 0.4614 - mean_absolute_percentage_error: 301.3977 - mean_squared_error: 0.4514 - root_mean_squared_error: 0.6718 - val_loss: 0.2236 - val_mae: 0.4778 - val_mean_absolute_percentage_error: 145.2780 - val_mean_squared_error: 0.4724 - val_root_mean_squared_error: 0.6873
# Epoch 10/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2114 - mae: 0.4563 - mean_absolute_percentage_error: 254.5763 - mean_squared_error: 0.4456 - root_mean_squared_error: 0.6674 - val_loss: 0.2228 - val_mae: 0.4767 - val_mean_absolute_percentage_error: 145.1219 - val_mean_squared_error: 0.4700 - val_root_mean_squared_error: 0.6855
# Epoch 11/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2046 - mae: 0.4423 - mean_absolute_percentage_error: 322.8881 - mean_squared_error: 0.4313 - root_mean_squared_error: 0.6565 - val_loss: 0.2257 - val_mae: 0.4897 - val_mean_absolute_percentage_error: 153.4804 - val_mean_squared_error: 0.4769 - val_root_mean_squared_error: 0.6906
# Epoch 12/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2137 - mae: 0.4584 - mean_absolute_percentage_error: 362.6795 - mean_squared_error: 0.4544 - root_mean_squared_error: 0.6740 - val_loss: 0.2218 - val_mae: 0.4732 - val_mean_absolute_percentage_error: 145.7424 - val_mean_squared_error: 0.4696 - val_root_mean_squared_error: 0.6853
# Epoch 13/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2090 - mae: 0.4551 - mean_absolute_percentage_error: 322.5348 - mean_squared_error: 0.4416 - root_mean_squared_error: 0.6644 - val_loss: 0.2226 - val_mae: 0.4782 - val_mean_absolute_percentage_error: 147.7414 - val_mean_squared_error: 0.4722 - val_root_mean_squared_error: 0.6871
# Epoch 14/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2117 - mae: 0.4593 - mean_absolute_percentage_error: 323.2884 - mean_squared_error: 0.4490 - root_mean_squared_error: 0.6700 - val_loss: 0.2214 - val_mae: 0.4735 - val_mean_absolute_percentage_error: 145.3236 - val_mean_squared_error: 0.4696 - val_root_mean_squared_error: 0.6853
# Epoch 15/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2101 - mae: 0.4512 - mean_absolute_percentage_error: 307.7897 - mean_squared_error: 0.4488 - root_mean_squared_error: 0.6699 - val_loss: 0.2213 - val_mae: 0.4720 - val_mean_absolute_percentage_error: 146.0849 - val_mean_squared_error: 0.4709 - val_root_mean_squared_error: 0.6862
# Epoch 16/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2167 - mae: 0.4599 - mean_absolute_percentage_error: 276.5121 - mean_squared_error: 0.4629 - root_mean_squared_error: 0.6800 - val_loss: 0.2216 - val_mae: 0.4763 - val_mean_absolute_percentage_error: 151.1466 - val_mean_squared_error: 0.4733 - val_root_mean_squared_error: 0.6880
# Epoch 17/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2102 - mae: 0.4564 - mean_absolute_percentage_error: 253.4192 - mean_squared_error: 0.4474 - root_mean_squared_error: 0.6688 - val_loss: 0.2205 - val_mae: 0.4708 - val_mean_absolute_percentage_error: 145.9619 - val_mean_squared_error: 0.4697 - val_root_mean_squared_error: 0.6853
# Epoch 18/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2167 - mae: 0.4639 - mean_absolute_percentage_error: 351.9930 - mean_squared_error: 0.4640 - root_mean_squared_error: 0.6809 - val_loss: 0.2207 - val_mae: 0.4735 - val_mean_absolute_percentage_error: 149.6580 - val_mean_squared_error: 0.4715 - val_root_mean_squared_error: 0.6867
# Epoch 19/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2158 - mae: 0.4570 - mean_absolute_percentage_error: 336.6107 - mean_squared_error: 0.4683 - root_mean_squared_error: 0.6837 - val_loss: 0.2258 - val_mae: 0.4855 - val_mean_absolute_percentage_error: 134.6415 - val_mean_squared_error: 0.4826 - val_root_mean_squared_error: 0.6947
# Epoch 20/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2187 - mae: 0.4675 - mean_absolute_percentage_error: 370.3499 - mean_squared_error: 0.4727 - root_mean_squared_error: 0.6872 - val_loss: 0.2202 - val_mae: 0.4778 - val_mean_absolute_percentage_error: 139.3372 - val_mean_squared_error: 0.4717 - val_root_mean_squared_error: 0.6868
# Epoch 21/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2091 - mae: 0.4516 - mean_absolute_percentage_error: 348.8134 - mean_squared_error: 0.4526 - root_mean_squared_error: 0.6726 - val_loss: 0.2197 - val_mae: 0.4681 - val_mean_absolute_percentage_error: 140.9869 - val_mean_squared_error: 0.4734 - val_root_mean_squared_error: 0.6880
# Epoch 22/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2021 - mae: 0.4445 - mean_absolute_percentage_error: 222.7348 - mean_squared_error: 0.4323 - root_mean_squared_error: 0.6574 - val_loss: 0.2201 - val_mae: 0.4692 - val_mean_absolute_percentage_error: 146.8841 - val_mean_squared_error: 0.4762 - val_root_mean_squared_error: 0.6901
# Epoch 23/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2063 - mae: 0.4442 - mean_absolute_percentage_error: 276.1389 - mean_squared_error: 0.4461 - root_mean_squared_error: 0.6677 - val_loss: 0.2203 - val_mae: 0.4744 - val_mean_absolute_percentage_error: 145.8459 - val_mean_squared_error: 0.4736 - val_root_mean_squared_error: 0.6882
# Epoch 24/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2119 - mae: 0.4552 - mean_absolute_percentage_error: 376.7492 - mean_squared_error: 0.4604 - root_mean_squared_error: 0.6783 - val_loss: 0.2190 - val_mae: 0.4658 - val_mean_absolute_percentage_error: 144.8742 - val_mean_squared_error: 0.4748 - val_root_mean_squared_error: 0.6891
# Epoch 25/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2113 - mae: 0.4487 - mean_absolute_percentage_error: 232.9855 - mean_squared_error: 0.4671 - root_mean_squared_error: 0.6833 - val_loss: 0.2200 - val_mae: 0.4713 - val_mean_absolute_percentage_error: 143.7699 - val_mean_squared_error: 0.4753 - val_root_mean_squared_error: 0.6894
# Epoch 26/35
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2068 - mae: 0.4418 - mean_absolute_percentage_error: 246.3187 - mean_squared_error: 0.4534 - root_mean_squared_error: 0.6731 - val_loss: 0.2182 - val_mae: 0.4663 - val_mean_absolute_percentage_error: 139.4634 - val_mean_squared_error: 0.4711 - val_root_mean_squared_error: 0.6864
# Epoch 27/35
# ...
# Epoch 11/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2706 - mae: 0.4646 - mean_absolute_percentage_error: 279.2696 - mean_squared_error: 0.4199 - root_mean_squared_error: 0.6479 - val_loss: 0.2891 - val_mae: 0.4826 - val_mean_absolute_percentage_error: 249.1251 - val_mean_squared_error: 0.4676 - val_root_mean_squared_error: 0.6838
# Epoch 12/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2616 - mae: 0.4594 - mean_absolute_percentage_error: 260.6964 - mean_squared_error: 0.4145 - root_mean_squared_error: 0.6437 - val_loss: 0.2844 - val_mae: 0.4901 - val_mean_absolute_percentage_error: 244.0601 - val_mean_squared_error: 0.4702 - val_root_mean_squared_error: 0.6857
# Epoch 13/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2651 - mae: 0.4686 - mean_absolute_percentage_error: 267.8164 - mean_squared_error: 0.4328 - root_mean_squared_error: 0.6577 - val_loss: 0.2768 - val_mae: 0.4863 - val_mean_absolute_percentage_error: 266.8453 - val_mean_squared_error: 0.4639 - val_root_mean_squared_error: 0.6811
# Epoch 14/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2537 - mae: 0.4593 - mean_absolute_percentage_error: 267.7875 - mean_squared_error: 0.4200 - root_mean_squared_error: 0.6481 - val_loss: 0.2726 - val_mae: 0.4895 - val_mean_absolute_percentage_error: 262.0708 - val_mean_squared_error: 0.4644 - val_root_mean_squared_error: 0.6815
# Epoch 15/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2445 - mae: 0.4569 - mean_absolute_percentage_error: 246.3830 - mean_squared_error: 0.4100 - root_mean_squared_error: 0.6402 - val_loss: 0.2681 - val_mae: 0.4837 - val_mean_absolute_percentage_error: 251.2715 - val_mean_squared_error: 0.4637 - val_root_mean_squared_error: 0.6810
# Epoch 16/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2452 - mae: 0.4678 - mean_absolute_percentage_error: 295.0589 - mean_squared_error: 0.4185 - root_mean_squared_error: 0.6469 - val_loss: 0.2648 - val_mae: 0.4899 - val_mean_absolute_percentage_error: 262.3627 - val_mean_squared_error: 0.4640 - val_root_mean_squared_error: 0.6811
# Epoch 17/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2392 - mae: 0.4596 - mean_absolute_percentage_error: 274.8831 - mean_squared_error: 0.4136 - root_mean_squared_error: 0.6430 - val_loss: 0.2608 - val_mae: 0.4798 - val_mean_absolute_percentage_error: 242.3872 - val_mean_squared_error: 0.4625 - val_root_mean_squared_error: 0.6801
# Epoch 18/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2365 - mae: 0.4559 - mean_absolute_percentage_error: 261.1526 - mean_squared_error: 0.4145 - root_mean_squared_error: 0.6436 - val_loss: 0.2577 - val_mae: 0.4807 - val_mean_absolute_percentage_error: 255.7522 - val_mean_squared_error: 0.4618 - val_root_mean_squared_error: 0.6796
# Epoch 19/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2353 - mae: 0.4629 - mean_absolute_percentage_error: 278.5842 - mean_squared_error: 0.4172 - root_mean_squared_error: 0.6458 - val_loss: 0.2563 - val_mae: 0.4859 - val_mean_absolute_percentage_error: 275.2728 - val_mean_squared_error: 0.4631 - val_root_mean_squared_error: 0.6805
# Epoch 20/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2354 - mae: 0.4644 - mean_absolute_percentage_error: 243.8702 - mean_squared_error: 0.4227 - root_mean_squared_error: 0.6501 - val_loss: 0.2537 - val_mae: 0.4845 - val_mean_absolute_percentage_error: 252.0384 - val_mean_squared_error: 0.4631 - val_root_mean_squared_error: 0.6805
# Epoch 21/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2252 - mae: 0.4556 - mean_absolute_percentage_error: 248.9782 - mean_squared_error: 0.4062 - root_mean_squared_error: 0.6371 - val_loss: 0.2511 - val_mae: 0.4839 - val_mean_absolute_percentage_error: 258.5767 - val_mean_squared_error: 0.4611 - val_root_mean_squared_error: 0.6791
# Epoch 22/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2278 - mae: 0.4615 - mean_absolute_percentage_error: 270.9570 - mean_squared_error: 0.4144 - root_mean_squared_error: 0.6437 - val_loss: 0.2503 - val_mae: 0.4841 - val_mean_absolute_percentage_error: 249.6748 - val_mean_squared_error: 0.4629 - val_root_mean_squared_error: 0.6804
# Epoch 23/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2295 - mae: 0.4652 - mean_absolute_percentage_error: 291.4334 - mean_squared_error: 0.4209 - root_mean_squared_error: 0.6486 - val_loss: 0.2490 - val_mae: 0.4835 - val_mean_absolute_percentage_error: 243.1818 - val_mean_squared_error: 0.4631 - val_root_mean_squared_error: 0.6805
# Epoch 24/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2234 - mae: 0.4547 - mean_absolute_percentage_error: 260.0954 - mean_squared_error: 0.4117 - root_mean_squared_error: 0.6415 - val_loss: 0.2486 - val_mae: 0.4939 - val_mean_absolute_percentage_error: 260.2686 - val_mean_squared_error: 0.4636 - val_root_mean_squared_error: 0.6809
# Epoch 25/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2322 - mae: 0.4680 - mean_absolute_percentage_error: 278.2573 - mean_squared_error: 0.4310 - root_mean_squared_error: 0.6564 - val_loss: 0.2461 - val_mae: 0.4769 - val_mean_absolute_percentage_error: 246.4542 - val_mean_squared_error: 0.4605 - val_root_mean_squared_error: 0.6786
# Epoch 26/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2258 - mae: 0.4661 - mean_absolute_percentage_error: 249.9768 - mean_squared_error: 0.4188 - root_mean_squared_error: 0.6471 - val_loss: 0.2512 - val_mae: 0.4945 - val_mean_absolute_percentage_error: 229.8294 - val_mean_squared_error: 0.4730 - val_root_mean_squared_error: 0.6878
# Epoch 27/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2257 - mae: 0.4678 - mean_absolute_percentage_error: 256.1512 - mean_squared_error: 0.4208 - root_mean_squared_error: 0.6485 - val_loss: 0.2474 - val_mae: 0.4973 - val_mean_absolute_percentage_error: 261.7408 - val_mean_squared_error: 0.4656 - val_root_mean_squared_error: 0.6823
# Epoch 28/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2158 - mae: 0.4529 - mean_absolute_percentage_error: 298.4979 - mean_squared_error: 0.4014 - root_mean_squared_error: 0.6334 - val_loss: 0.2473 - val_mae: 0.4902 - val_mean_absolute_percentage_error: 239.4170 - val_mean_squared_error: 0.4667 - val_root_mean_squared_error: 0.6831
# Epoch 29/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.2240 - mae: 0.4617 - mean_absolute_percentage_error: 315.3356 - mean_squared_error: 0.4188 - root_mean_squared_error: 0.6469 - val_loss: 0.2457 - val_mae: 0.4848 - val_mean_absolute_percentage_error: 245.6688 - val_mean_squared_error: 0.4639 - val_root_mean_squared_error: 0.6811
# Epoch 30/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2172 - mae: 0.4558 - mean_absolute_percentage_error: 288.5349 - mean_squared_error: 0.4054 - root_mean_squared_error: 0.6366 - val_loss: 0.2459 - val_mae: 0.4907 - val_mean_absolute_percentage_error: 249.0114 - val_mean_squared_error: 0.4648 - val_root_mean_squared_error: 0.6818
# Epoch 31/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.2262 - mae: 0.4646 - mean_absolute_percentage_error: 268.1782 - mean_squared_error: 0.4243 - root_mean_squared_error: 0.6513 - val_loss: 0.2436 - val_mae: 0.4773 - val_mean_absolute_percentage_error: 244.8529 - val_mean_squared_error: 0.4604 - val_root_mean_squared_error: 0.6786
# Epoch 32/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.2272 - mae: 0.4698 - mean_absolute_percentage_error: 243.5309 - mean_squared_error: 0.4268 - root_mean_squared_error: 0.6531 - val_loss: 0.2433 - val_mae: 0.4809 - val_mean_absolute_percentage_error: 252.0368 - val_mean_squared_error: 0.4603 - val_root_mean_squared_error: 0.6785
# Epoch 33/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2232 - mae: 0.4612 - mean_absolute_percentage_error: 250.6788 - mean_squared_error: 0.4192 - root_mean_squared_error: 0.6474 - val_loss: 0.2427 - val_mae: 0.4759 - val_mean_absolute_percentage_error: 245.0367 - val_mean_squared_error: 0.4591 - val_root_mean_squared_error: 0.6776
# Epoch 34/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2233 - mae: 0.4643 - mean_absolute_percentage_error: 259.8314 - mean_squared_error: 0.4191 - root_mean_squared_error: 0.6472 - val_loss: 0.2447 - val_mae: 0.4819 - val_mean_absolute_percentage_error: 237.7355 - val_mean_squared_error: 0.4639 - val_root_mean_squared_error: 0.6811
# Epoch 35/35
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2250 - mae: 0.4613 - mean_absolute_percentage_error: 288.9788 - mean_squared_error: 0.4234 - root_mean_squared_error: 0.6506 - val_loss: 0.2439 - val_mae: 0.4868 - val_mean_absolute_percentage_error: 242.9486 - val_mean_squared_error: 0.4624 - val_root_mean_squared_error: 0.6800
# Epoch 1/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.0436 - mae: 0.1431 - mean_absolute_percentage_error: 51.8749 - mean_squared_error: 0.0630 - root_mean_squared_error: 0.2479 - val_loss: 0.0323 - val_mae: 0.1181 - val_mean_absolute_percentage_error: 24.9064 - val_mean_squared_error: 0.0424 - val_root_mean_squared_error: 0.2060
# Epoch 2/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.0372 - mae: 0.1272 - mean_absolute_percentage_error: 44.8434 - mean_squared_error: 0.0526 - root_mean_squared_error: 0.2289 - val_loss: 0.0310 - val_mae: 0.1130 - val_mean_absolute_percentage_error: 22.6825 - val_mean_squared_error: 0.0417 - val_root_mean_squared_error: 0.2041
# Epoch 3/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0347 - mae: 0.1205 - mean_absolute_percentage_error: 51.2742 - mean_squared_error: 0.0491 - root_mean_squared_error: 0.2210 - val_loss: 0.0281 - val_mae: 0.0848 - val_mean_absolute_percentage_error: 22.3124 - val_mean_squared_error: 0.0365 - val_root_mean_squared_error: 0.1911
# Epoch 4/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0330 - mae: 0.1191 - mean_absolute_percentage_error: 49.8511 - mean_squared_error: 0.0465 - root_mean_squared_error: 0.2155 - val_loss: 0.0277 - val_mae: 0.0831 - val_mean_absolute_percentage_error: 22.4114 - val_mean_squared_error: 0.0365 - val_root_mean_squared_error: 0.1910
# Epoch 5/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0351 - mae: 0.1244 - mean_absolute_percentage_error: 50.2545 - mean_squared_error: 0.0515 - root_mean_squared_error: 0.2267 - val_loss: 0.0273 - val_mae: 0.0787 - val_mean_absolute_percentage_error: 22.5405 - val_mean_squared_error: 0.0360 - val_root_mean_squared_error: 0.1896
# Epoch 6/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0322 - mae: 0.1172 - mean_absolute_percentage_error: 52.7584 - mean_squared_error: 0.0461 - root_mean_squared_error: 0.2137 - val_loss: 0.0283 - val_mae: 0.0968 - val_mean_absolute_percentage_error: 22.7948 - val_mean_squared_error: 0.0387 - val_root_mean_squared_error: 0.1967
# Epoch 7/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0317 - mae: 0.1168 - mean_absolute_percentage_error: 50.3792 - mean_squared_error: 0.0454 - root_mean_squared_error: 0.2123 - val_loss: 0.0300 - val_mae: 0.1214 - val_mean_absolute_percentage_error: 28.2102 - val_mean_squared_error: 0.0423 - val_root_mean_squared_error: 0.2056
# Epoch 8/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0360 - mae: 0.1264 - mean_absolute_percentage_error: 56.3166 - mean_squared_error: 0.0543 - root_mean_squared_error: 0.2326 - val_loss: 0.0287 - val_mae: 0.1074 - val_mean_absolute_percentage_error: 23.7250 - val_mean_squared_error: 0.0403 - val_root_mean_squared_error: 0.2007
# Epoch 9/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0338 - mae: 0.1195 - mean_absolute_percentage_error: 53.6497 - mean_squared_error: 0.0503 - root_mean_squared_error: 0.2239 - val_loss: 0.0276 - val_mae: 0.0928 - val_mean_absolute_percentage_error: 24.2709 - val_mean_squared_error: 0.0379 - val_root_mean_squared_error: 0.1948
# Epoch 10/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0383 - mae: 0.1306 - mean_absolute_percentage_error: 54.7047 - mean_squared_error: 0.0596 - root_mean_squared_error: 0.2422 - val_loss: 0.0283 - val_mae: 0.0986 - val_mean_absolute_percentage_error: 25.6682 - val_mean_squared_error: 0.0394 - val_root_mean_squared_error: 0.1984
# Epoch 11/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0332 - mae: 0.1200 - mean_absolute_percentage_error: 51.3573 - mean_squared_error: 0.0496 - root_mean_squared_error: 0.2223 - val_loss: 0.0282 - val_mae: 0.1042 - val_mean_absolute_percentage_error: 25.8210 - val_mean_squared_error: 0.0394 - val_root_mean_squared_error: 0.1984
# Epoch 12/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0313 - mae: 0.1131 - mean_absolute_percentage_error: 50.7488 - mean_squared_error: 0.0459 - root_mean_squared_error: 0.2138 - val_loss: 0.0294 - val_mae: 0.1154 - val_mean_absolute_percentage_error: 24.0313 - val_mean_squared_error: 0.0425 - val_root_mean_squared_error: 0.2062
# Epoch 13/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0336 - mae: 0.1201 - mean_absolute_percentage_error: 49.4524 - mean_squared_error: 0.0508 - root_mean_squared_error: 0.2249 - val_loss: 0.0265 - val_mae: 0.0799 - val_mean_absolute_percentage_error: 22.6003 - val_mean_squared_error: 0.0365 - val_root_mean_squared_error: 0.1911
# Epoch 14/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0340 - mae: 0.1232 - mean_absolute_percentage_error: 60.2667 - mean_squared_error: 0.0517 - root_mean_squared_error: 0.2272 - val_loss: 0.0263 - val_mae: 0.0776 - val_mean_absolute_percentage_error: 21.3269 - val_mean_squared_error: 0.0364 - val_root_mean_squared_error: 0.1909
# Epoch 15/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0342 - mae: 0.1206 - mean_absolute_percentage_error: 48.8877 - mean_squared_error: 0.0523 - root_mean_squared_error: 0.2285 - val_loss: 0.0283 - val_mae: 0.0977 - val_mean_absolute_percentage_error: 26.1085 - val_mean_squared_error: 0.0401 - val_root_mean_squared_error: 0.2004
# Epoch 16/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0319 - mae: 0.1158 - mean_absolute_percentage_error: 50.4231 - mean_squared_error: 0.0479 - root_mean_squared_error: 0.2185 - val_loss: 0.0286 - val_mae: 0.1021 - val_mean_absolute_percentage_error: 26.2367 - val_mean_squared_error: 0.0410 - val_root_mean_squared_error: 0.2026
# Epoch 17/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0322 - mae: 0.1187 - mean_absolute_percentage_error: 52.5378 - mean_squared_error: 0.0485 - root_mean_squared_error: 0.2202 - val_loss: 0.0267 - val_mae: 0.0856 - val_mean_absolute_percentage_error: 24.1842 - val_mean_squared_error: 0.0374 - val_root_mean_squared_error: 0.1934
# Epoch 18/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0324 - mae: 0.1177 - mean_absolute_percentage_error: 51.9899 - mean_squared_error: 0.0490 - root_mean_squared_error: 0.2212 - val_loss: 0.0280 - val_mae: 0.1076 - val_mean_absolute_percentage_error: 24.5808 - val_mean_squared_error: 0.0405 - val_root_mean_squared_error: 0.2013
# Epoch 19/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0356 - mae: 0.1244 - mean_absolute_percentage_error: 53.3477 - mean_squared_error: 0.0555 - root_mean_squared_error: 0.2348 - val_loss: 0.0267 - val_mae: 0.0850 - val_mean_absolute_percentage_error: 24.5487 - val_mean_squared_error: 0.0376 - val_root_mean_squared_error: 0.1938
# Epoch 20/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0331 - mae: 0.1225 - mean_absolute_percentage_error: 52.4568 - mean_squared_error: 0.0507 - root_mean_squared_error: 0.2246 - val_loss: 0.0273 - val_mae: 0.0971 - val_mean_absolute_percentage_error: 27.3968 - val_mean_squared_error: 0.0392 - val_root_mean_squared_error: 0.1980
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# SAI
# Best seq: 5
# Best number of layer LSTM: 3
# Number of units in Dense 1: 32
# Number of units in Dense 2: 32
# Number of units in Dense 3: 64
# Number of units in Dense: 160
# Best optimizer: rmsprop

# %% [markdown]
# ### Explanation of Variables:
#
# - `type_objective`: The objective to be optimized during tuning (e.g., 'mean_squared_error', 'mae').
# - `driver`: The driver identifier, used to load specific training and race data for each driver.
# - `train_data`: Pandas DataFrame containing the scaled training data for the driver.
# - `race_data`: Pandas DataFrame containing the scaled race data for the driver.
# - `X_train_data`, `y_train_data`: The training input features and target variable (lap times) for the model.
# - `X_race_data`, `y_race_data`: The race input features and target variable (lap times).
# - `tuner`: Keras Tuner object, used to search for optimal hyperparameters using Hyperband.
# - `SEQ_LENGTH`: The number of time steps used to create sequences for the LSTM input.
# - `X_train_seq`, `y_train_seq`: Sequences of input features and target values, generated from the training data.
# - `X_race_seq`, `y_race_seq`: Sequences of input features and target values, generated from the race data.
# - `best_hps`: The optimal hyperparameters found during the tuning process.
# - `history_train`: The training history of the model, used for analysis of training performance.
# - `history_race`: The race data history, used for analysis of how the model performs on race data.
# - `all_histories_train`, `all_histories_race`: Lists storing training and race histories for each driver.

# %%
# Importing the necessary library for plotting
import matplotlib.pyplot as plt

# Function to plot the training and validation loss for each driver
def plot_training_history(history_train, history_race, driver):
    """
    Plots the training and validation loss for both the training and race datasets for a given driver.

    Parameters:
    - history_train (keras.callbacks.History): The training history object, which contains the loss values
      and validation loss values for the training data over the epochs.
    - history_race (keras.callbacks.History): The training history object for race data, which stores the
      loss and validation loss values over the epochs.
    - driver (str): The driver's identifier (e.g., 'VER', 'HAM') used to label the plot.

    This function creates two subplots:
    1. The first subplot shows the training and validation loss for the training data.
    2. The second subplot shows the training and validation loss for the race data.
    """

    # Create a new figure for the plots with a specified size
    plt.figure(figsize=(14, 6))

    # First subplot: Training Loss and Validation Loss for the training data
    plt.subplot(1, 2, 1)
    plt.plot(history_train.history['loss'], label='Training Loss')  # Plot training loss over epochs
    plt.plot(history_train.history['val_loss'], label='Validation Loss')  # Plot validation loss over epochs
    plt.title(f'Training Loss for {driver}')  # Set the title for the training plot
    plt.xlabel('Epochs')  # X-axis label
    plt.ylabel('Loss')  # Y-axis label (loss values)
    plt.legend()  # Add a legend to distinguish between training and validation loss

    # Second subplot: Training Loss and Validation Loss for the race data
    plt.subplot(1, 2, 2)
    plt.plot(history_race.history['loss'], label='Race Training Loss')  # Plot race training loss over epochs
    plt.plot(history_race.history['val_loss'], label='Race Validation Loss')  # Plot race validation loss over epochs
    plt.title(f'Race Loss for {driver}')  # Set the title for the race plot
    plt.xlabel('Epochs')  # X-axis label
    plt.ylabel('Loss')  # Y-axis label (loss values)
    plt.legend()  # Add a legend to distinguish between race training and validation loss

    # Adjust the layout of the plots to avoid overlap
    plt.tight_layout()

    # Display the plots
    plt.show()

# Plot training and validation performance for each driver
for i, driver in enumerate(driver_list):
    """
    Looping through each driver in the driver_list and plotting the training history and race history
    using the plot_training_history function.

    Parameters:
    - i (int): The index of the current driver in the driver_list.
    - driver (str): The driver's identifier (e.g., 'VER', 'HAM').
    - all_histories_train (list): A list of training history objects for each driver.
    - all_histories_race (list): A list of race history objects for each driver.

    For each driver, the function retrieves the corresponding training and race history,
    then calls the plot_training_history function to create the plots.
    """
    plot_training_history(all_histories_train[i], all_histories_race[i], driver)
